# %% [markdown]
# 0. Import modules

# %%
from support_pyfile import *
from additional_support_pyfile import *
from instance_pyfile import *

import time

# %% [markdown]
# 1. Config the LLM

# %%
import google.generativeai as genai

generation_config = {
    "temperature":0,
    "top_p":1,
    "top_k":1,
    "max_output_tokens":2048,
}

safety_settings = [
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_NONE"
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_NONE"
    }, 
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_NONE"
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_NONE"
    },
]


genai.configure(api_key='YOUR_API_KEY')

model = genai.GenerativeModel(model_name='gemini-pro', safety_settings=safety_settings)

# %% [markdown]
# 2. Prompt for crossover operator
# - Code: OX operator and PMX operator
# - prompt = (TSP_description + code) + operator_codes + examples + task_instruction

# %%
crx_description = 'You are given a list of points with coordinates: {' + list2str() + '}. A solution is a trace, with the shortest possible length, that traveles each point exactly once.\n'
crx_description += 'You will be given 2 parent solutions, your task is ONLY use one of the 2 Crossover operators provided below on the 2 parent solutions and generate 2 new Offsprings.'

trace_samples = 'Below are some previous traces and their lengths. The traces are arranged in descending order based on their lengths, where lower values are better.\n'
# remember to reduce N compare to the last algo

in_context = 'Now, there are Python code and some examples of the first Crossover operator. The examples consist of 2 parent traces and 2 new generated traces with explanations:\n'
in_context += ('import random \n def first_operator(parent1, parent2): \n size = len(parent1) \n #Step 1: Select random crossover range in both 2 parents, avoid the first and last gene \n start, end = sorted(random.sample(range(1, size-2), 2)) \n #Step 2: Create offspring by exchanging the selected range \n child1 = parent1[:start] + parent2[start:end] + parent1[end:] \n child2 = parent2[:start] + parent1[start:end] + parent2[end:] \n #Step 3: Determine the mapping relationship to legalize offspring \n mapping1 = {parent2[i]: parent1[i] for i in range(start, end)' + '}\n' + 'mapping 2 = {parent1[i]: parent2[i] for i in range(start, end)' + '}\n' + '#Step 4: Legalize children with the mapping relationship\n for i in list(range(start)) + list(range(end, size)): \n if child1[i] in mapping1:\n while child1[i] in mapping1: \n child1[i] = mapping1[child1[i]] \n if child2[i] in mapping2:\n while child2[i] in mapping2: \n child2[i] = mapping[child2[i]]\n return (child1, child2) \n return child1, child2 \n')
in_context += '{parent1 = [10, 5, 3, 19, 18, 11, 2, 14, 20, 12, 7, 21, 8, 6, 1, 17, 4, 9, 15, 13, 16, 22], parent2 = [20, 1, 4, 6, 2, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, 18, 17, 22]} {child1: [10, 1, 4, 6, 2, 11, 18, 14, 20, 12, 7, 21, 8, 19, 5, 17, 3, 9, 15, 13, 16, 22], child2: [20, 5, 3, 19, 18, 11, 8, 10, 6, 7, 9, 1, 12, 21, 13, 15, 16, 14, 4, 2, 17, 22]} Explanation: {Step 1: Select random crossover range in both 2 parents: (start=1, end=5); Step 2: Create offspring by exchanging the selected range: (child1=[10, 1, 4, 6, 2, 11, 2, 14, 20, 12, 7, 21, 8, 6, 1, 17, 4, 9, 15, 13, 16, 22], child2=[20, 5, 3, 19, 18, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, 18, 17, 22]); Step 3: Determine the mapping relationship to legalize offspring: (mapping1={1: 5, 4: 3, 6: 19, 2: 18}, mapping2={5: 1, 3: 4, 19: 6, 18: 2}); Step 4: Legalize children with the mapping relationsip and receive 2 result offsprings as shown.}\n'
in_context += '{parent1 = [10, 5, 3, 19, 18, 11, 2, 14, 20, 12, 7, 21, 8, 6, 1, 17, 4, 9, 15, 13, 16, 22], parent2 = [14, 19, 6, 21, 8, 5, 10, 1, 4, 13, 12, 18, 7, 11, 20, 3, 15, 16, 2, 9, 17, 22]} {child1: [2, 3, 6, 21, 8, 5, 10, 1, 4, 13, 12, 18, 7, 11, 20, 17, 14, 9, 15, 19, 16, 22], child2: [4, 13, 3, 19, 18, 11, 2, 14, 20, 12, 7, 21, 8, 6, 1, 5, 15, 16, 10, 9, 17, 22]} Explanation: {Step 1: Select random crossover range in both 2 parents: (start=2, end=15); Step 2: Create offspring by exchanging the selected range: (child1=[10, 5, 6, 21, 8, 5, 10, 1, 4, 13, 12, 18, 7, 11, 20, 17, 4, 9, 15, 13, 16, 22], child2=[14, 19, 3, 19, 18, 11, 2, 14, 20, 12, 7, 21, 8, 6, 1, 3, 15, 16, 2, 9, 17, 22]); Step 3: Determine the mapping relationship to legalize offspring: (mapping1={6: 3, 21: 19, 8: 18, 5: 11, 10: 2, 1: 14, 4: 20, 13: 12, 12: 7, 18: 21, 7: 8, 11: 6, 20: 1}, mapping2={3: 6, 19: 21, 18: 8, 11: 5, 2: 10, 14: 1, 20: 4, 12: 13, 7: 12, 21: 18, 8: 7, 6: 11, 1: 20}); Step 4: Legalize children with the mapping relationsip and receive 2 result offsprings as shown.}\n'
in_context += '{parent1 = [20, 1, 4, 6, 2, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, 18, 17, 22], parent2 = [14, 19, 6, 21, 8, 5, 10, 1, 4, 13, 12, 18, 7, 11, 20, 3, 15, 16, 2, 9, 17, 22]} {child1: [20, 8, 19, 6, 2, 21, 10, 1, 4, 13, 12, 18, 7, 11, 9, 15, 16, 14, 3, 5, 17, 22], child2: [14, 4, 6, 11, 1, 18, 8, 10, 19, 7, 9, 5, 12, 21, 20, 3, 15, 16, 2, 13, 17, 22]} Explanation: {Step 1: Select random crossover range in both 2 parents: (start=6, end=14); Step 2: Create offspring by exchanging the selected range: (child1=[20, 1, 4, 6, 2, 11, 10, 1, 4, 13, 12, 18, 7, 11, 13, 15, 16, 14, 3, 18, 17, 22], child2=[14, 19, 6, 21, 8, 5, 8, 10, 19, 7, 9, 5, 12, 21, 20, 3, 15, 16, 2, 9, 17, 22]); Step 3: Determine the mapping relationship to legalize offspring: (mapping1={10: 8, 1: 10, 4: 19, 13: 7, 12: 9, 18: 5, 7: 12, 11: 21}, mapping2={8: 10, 10: 1, 19: 4, 7: 13, 9: 12, 5: 18, 12: 7, 21: 11}); Step 4: Legalize children with the mapping relationsip and receive 2 result offsprings as shown.}\n'

in_context += 'Now, there are Python code and some examples of the second Crossover operator. The examples consist of 2 parent traces and 2 new generated traces with explanations:\n'
in_context += 'import random \n def second_operator(parent1, parent2): \n size = len(parent1) \n #Step 1: Select random crossover range in both 2 parents, avoid the first and last gene \n start, end = sorted(random.sample(range(1, size-2), 2)) \n # Step 2: Create proto-child by inheriting the selected range from its parent \n child1 = [None]*len(parent1) \n child1[start:end] = parent1[start:end] \n child2 = [None]*len(parent2) \n child2[start:end] = parent2[start:end] \n #Step 3: Fill in remaining positions in child1 with other cities in parent2 \n for i in range(len(parent2)):\n if parent2[i] not in child1:\n child1[child1.index(None)] = parent2[i] \n #Step 4: Fill in remaining positions in child2 with other cities in parent1: \n for i in range(len(parent1)):\n if parent1[i] not in child2:\n child2[child2.index(None)] = parent1[i] \n return child1, child2 \n'
in_context += '{parent1 = [20, 1, 4, 6, 2, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, 18, 17, 22], parent2 = [6, 8, 20, 1, 19, 21, 10, 11, 7, 12, 5, 9, 4, 3, 15, 16, 2, 14, 13, 18, 17, 22]} {child1: [6, 20, 1, 11, 4, 2, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, 18, 17, 22], child2: [20, 1, 6, 8, 19, 21, 10, 11, 7, 12, 5, 9, 4, 3, 15, 16, 2, 14, 13, 18, 17, 22]} Explanation: {Step 1: Select random crossover range in both 2 parents: (start=6, end=19); Step 2: Create proto-child by inheriting the selected range from its parent: (child1=[None, None, None, None, None, None, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, None, None, None], child2=[None, None, None, None, None, None, 10, 11, 7, 12, 5, 9, 4, 3, 15, 16, 2, 14, 13, None, None, None]); Step 3: Fill in remaining positions in child1 with other cities in parent2: child1=[6, 20, 1, 11, 4, 2, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, 18, 17, 22]; Step 4: Fill in remaining positions in child2 with other cities in parent1: child2=[20, 1, 6, 8, 19, 21, 10, 11, 7, 12, 5, 9, 4, 3, 15, 16, 2, 14, 13, 18, 17, 22]}\n'
in_context += '{parent1 = [16, 22, 15, 13, 14, 19, 6, 21, 8, 5, 10, 1, 4, 3, 12, 18, 7, 11, 20, 9, 17, 2], parent2 = [3, 12, 21, 8, 10, 19, 7, 11, 20, 1, 4, 6, 2, 14, 13, 16, 22, 15, 17, 18, 5, 9]} {child1: [21, 19, 6, 2, 14, 13, 16, 22, 8, 5, 10, 1, 4, 3, 12, 18, 7, 11, 20, 15, 17, 9], child2: [19, 21, 8, 5, 10, 3, 12, 18, 20, 1, 4, 6, 2, 14, 13, 16, 22, 15, 17, 7, 11, 9]} Explanation: {Step 1: Select random crossover range in both 2 parents: (start=8, end=19); Step 2: Create proto-child by inheriting the selected range from its parent: (child1=[None, None, None, None, None, None, None, None, 8, 5, 10, 1, 4, 3, 12, 18, 7, 11, 20, None, None, None], child2=[None, None, None, None, None, None, None, None, 20, 1, 4, 6, 2, 14, 13, 16, 22, 15, 17, None, None, None]); Step 3: Fill in remaining positions in child1 with other cities in parent2: child1=[21, 19, 6, 2, 14, 13, 16, 22, 8, 5, 10, 1, 4, 3, 12, 18, 7, 11, 20, 15, 17, 9]; Step 4: Fill in remaining positions in child2 with other cities in parent1: child2=[19, 21, 8, 5, 10, 3, 12, 18, 20, 1, 4, 6, 2, 14, 13, 16, 22, 15, 17, 7, 11, 9]}\n'
in_context += '{parent1 = [16, 22, 15, 13, 14, 19, 6, 21, 8, 5, 10, 1, 4, 3, 12, 18, 7, 11, 20, 9, 17, 2], parent2 = [1, 4, 6, 2, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, 18, 17, 22, 20]} {child1: [2, 11, 15, 13, 14, 19, 6, 21, 8, 5, 10, 1, 4, 3, 12, 18, 7, 9, 16, 17, 22, 20], child2: [22, 1, 6, 2, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 4, 3, 18, 20, 17]} Explanation: {Step 1: Select random crossover range in both 2 parents: (start=2, end=17); Step 2: Create proto-child by inheriting the selected range from its parent: (child1=[None, None, 15, 13, 14, 19, 6, 21, 8, 5, 10, 1, 4, 3, 12, 18, 7, None, None, None, None, None], child2=[None, None, 6, 2, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, None, None, None, None, None]); Step 3: Fill in remaining positions in child1 with other cities in parent2: child1=[2, 11, 15, 13, 14, 19, 6, 21, 8, 5, 10, 1, 4, 3, 12, 18, 7, 9, 16, 17, 22, 20]; Step 4: Fill in remaining positions in child2 with other cities in parent1: child2=[22, 1, 6, 2, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 4, 3, 18, 20, 17]}\n'

crx_task = 'Please follow the instruction step-by-step to generate 2 new offsprings:\n'
crx_task += '1. Now, you are given 2 parent solution traces: '
crx_task2 = '2. You can use ONE of the 2 mentioned Crossover Operators with the two traces in Step 1 to generate 2 new Offspring traces.'
crx_task2 += 'Directly give me 2 Offspring traces, bracketed the first Offspring with <Off1> and </Off1> and bracketed the second one with <Off2> and </Off2>. Not any explanation needed.'

# %% [markdown]
# 3. Prompt for Mutation Operator
# - Code: Towrs(), CIM(), RSM()
# - prompt = (TSP_description + examples) + operator_code + 3 examples + task_instruction

# %%
mut_description = 'You are given a list of points with coordinates: {' + list2str() + '}. A solution is a trace, with the shortest possible length, that traveles each point exactly once.\n'
mut_description += 'You now be given 1 solution traces, your task is to do Mutation it and give me the result.\n'

m_context = 'Now, there are Python code and some examples of the first Mutation operator. The examples consist of origin trace and the new generated trace with explanations:\n'
m_context += 'import random \n def first_operator(origin_trace): \n size = len(origin_trace) \n #Step 1: Randomly select 2 positions in the original trace \n position1, position2 = random.sample(range(1, size - 2), 2) \n # Step 2: Swap 2 genes in the positions selected aboved \n origin_trace[position1], origin_trace[position2] = origin_trace[position2], origin_trace[position1] \n'
m_context += '{origin_trace = [10, 14, 9, 8, 1, 6, 5, 11, 3, 12, 7, 13, 4, 2]}; {mutated_trace = [10, 14, 11, 8, 1, 6, 5, 9, 3, 12, 7, 13, 4, 2]} Explanation: {Step 1: Randomly select 2 positions in the original trace: (position1 = 2, position2 = 7); Step 2: Swap 2 genes in the positions selected aboved to get the mutated_trace = [10, 14, 11, 8, 1, 6, 5, 9, 3, 12, 7, 13, 4, 2]}\n'
m_context += '{origin_trace = [3, 2, 10, 7, 6, 11, 14, 1, 9, 13, 12, 5, 8, 4]}; {mutated_trace = [3, 9, 10, 7, 6, 11, 14, 1, 2, 13, 12, 5, 8, 4]} Explanation: {Step 1: Randomly select 2 positions in the original trace: (position1 = 8, position2 = 1); Step 2: Swap 2 genes in the positions selected aboved to get the mutated_trace = [3, 9, 10, 7, 6, 11, 14, 1, 2, 13, 12, 5, 8, 4]}\n'
m_context += '{origin_trace = [8, 7, 12, 14, 1, 3, 11, 6, 10, 4, 9, 13, 5, 2]}; {mutated_trace = [8, 7, 12, 14, 1, 3, 10, 6, 11, 4, 9, 13, 5, 2]} Explanation: {Step 1: Randomly select 2 positions in the original trace: (position1 = 6, position2 = 8); Step 2: Swap 2 genes in the positions selected aboved to get the mutated_trace = [8, 7, 12, 14, 1, 3, 10, 6, 11, 4, 9, 13, 5, 2]}\n'

m_context += 'Now, there are Python code and some examples of the second Mutation operator. The examples consist of origin trace and the new generated trace with explanations:\n'
m_context += 'import random \n def second_operator(origin_trace): \n size = len(origin_trace) \n #Step 1: Select a random point in the original trace \n point = random.randint(0, size - 1) \n # Step 2: Reverse all the sub-sequences from 0 to point and from point + 1 to the end \n     mutated_trace = origin_trace[:point][::-1] + origin_trace[point:][::-1] \n return mutated_trace \n'
m_context += '{origin_trace = [4, 1, 5, 14, 3, 9, 11, 7, 12, 13, 2, 8, 6, 10]}; {mutated_trace = [5, 1, 4, 10, 6, 8, 2, 13, 12, 7, 11, 9, 3, 14]} Explanation: {Step 1: Select a random point in the original trace: (point = 3); Step 2: Reverse all the sub-sequences from index = 0 to 3  and from index = 4 to the end of origin_trace, and get mutated_trace = [5, 1, 4, 10, 6, 8, 2, 13, 12, 7, 11, 9, 3, 14]}\n'
m_context += '{origin_trace = [10, 7, 5, 4, 9, 12, 3, 6, 14, 8, 1, 11, 13, 2]}; {mutated_trace = [14, 6, 3, 12, 9, 4, 5, 7, 10, 2, 13, 11, 1, 8]} Explanation: {Step 1: Select a random point in the original trace: (point = 9); Step 2: Reverse all the sub-sequences from index = 0 to 9  and from index = 10 to the end of origin_trace, and get mutated_trace = [14, 6, 3, 12, 9, 4, 5, 7, 10, 2, 13, 11, 1, 8]}\n'
m_context += '{origin_trace = [4, 6, 14, 9, 8, 10, 7, 13, 2, 1, 5, 3, 12, 11]}; {mutated_trace = [12, 3, 5, 1, 2, 13, 7, 10, 8, 9, 14, 6, 4, 11]} Explanation: {Step 1: Select a random point in the original trace: (point = 13); Step 2: Reverse all the sub-sequences from index = 0 to 13  and from index = 14 to the end of origin_trace, and get mutated_trace = [12, 3, 5, 1, 2, 13, 7, 10, 8, 9, 14, 6, 4, 11]}\n'

m_context += 'Now, there are Python code and some examples of the third Mutation operator. The examples consists of origin trace and the new generated trace with explanations.\n'
m_context += 'import random \n def third_operator(origin_trace): \n size = len(origin_trace) \n #Step 1: Select reverse range at random \n start, end = sorted(random.sample(range(1, size - 1), 2)) \n #Step 2: Reverse the sub-sequence from start to end to have the mutated trace \n     mutated_trace = origin_trace[:start] + origin_trace[start:end][::-1] + origin_trace[end:] \n return mutated_trace \n'
m_context += '{origin_trace = [1, 4, 13, 7, 10, 12, 6, 3, 8, 2, 11, 9, 5, 14]}; {mutated_trace = [1, 4, 13, 7, 10, 12, 8, 3, 6, 2, 11, 9, 5, 14]} Explanation: {Step 1: Select reverse range at random: (start = 6, end = 9); Step 2: Reverse the sub-sequence from index = 6 to 9 to have the mutated trace: [1, 4, 13, 7, 10, 12, 8, 3, 6, 2, 11, 9, 5, 14]}\n'
m_context += '{origin_trace = [2, 14, 4, 7, 10, 3, 8, 5, 1, 11, 12, 13, 6, 9]}; {mutated_trace = [2, 14, 4, 7, 10, 3, 8, 5, 1, 11, 12, 13, 6, 9]} Explanation: {Step 1: Select reverse range at random: (start = 6, end = 7); Step 2: Reverse the sub-sequence from index = 6 to 7 to have the mutated trace: [2, 14, 4, 7, 10, 3, 8, 5, 1, 11, 12, 13, 6, 9]}\n'
m_context += '{origin_trace = [14, 10, 5, 2, 13, 7, 12, 4, 8, 1, 3, 11, 6, 9]}; {mutated_trace = [14, 10, 5, 2, 13, 7, 1, 8, 4, 12, 3, 11, 6, 9]} Explanation: {Step 1: Select reverse range at random: (start = 6, end = 10); Step 2: Reverse the sub-sequence from index = 6 to 10 to have the mutated trace: [14, 10, 5, 2, 13, 7, 1, 8, 4, 12, 3, 11, 6, 9]}\n'

mut_task = 'Please follow the instruction step-by-step to generate 1 new mutated trace:\n'
mut_task += '1. Now, you are given a solution trace: '
mut_task2 = '2. You CAN use ONE of the 3 Mutation Operators aboved or combine them and generate NEW operator to mutate the given original trace in Step 1.'
mut_task2 += 'Directly give me the result, bracketed it with <mut> and </mut>. Not any explanation needed.'

# %%
best_cur = 99999999
best_now = 9999990

Pool = randomFirstN(n, N)

g = 1

# %%
while (g <= G and not check_stuck(best_cur, best_now, K=10)) :

    best_cur = Pool[N-1].length

    Pool_sharp = []

    for i in range(1, N+1) :
        
        par1, par2 = tournament_selection(Pool)

        print(f"{i}th pairs of parents in generation {g}:")

        print(f"parent_1: {par1}, parent_2: {par2}")

        if (random.random() < 0.7) :

            crosOv_prompt = crx_description + (trace_samples + pool2examples(Pool)) + in_context + crx_task + parent2str(par1, par2) + crx_task2

            start_time = time.time()

            response = model.generate_content(contents=crosOv_prompt)

            spent_time = time.time() - start_time

            print(f"spent_time for this request: {spent_time}")

            print(f"crossover of {i}th parents in generation {g}")
            child1, child2 = cut2Offsprings(response.text)
            #print(child1, child2)

            if checkPermu(child1, n):
                print("child1 accepted!")
                Pool_sharp.append(Individual(trace=traceStr2list(child1), length=objective_TSP(traceStr2list(child1))))
            if checkPermu(child2, n):
                print("child2 accepted!")
                Pool_sharp.append(Individual(trace=traceStr2list(child2), length=objective_TSP(traceStr2list(child2))))

            if (random.random() < 0.2) :

                for childStr in [child1, child2]:

                    mutate_prompt = mut_description + (trace_samples + pool2examples(Pool)) + m_context + (mut_task + childStr) + mut_task2

                    start_mut_time = time.time()

                    response_mut = model.generate_content(contents=mutate_prompt)

                    spent_time_mut = time.time() - start_mut_time

                    print(f"time for muatating: {spent_time_mut}")

                    sharp_childstr = cutMutated(response_mut.text)

                    if checkPermu(sharp_childstr, n):
                        Pool_sharp.append(Individual(trace=traceStr2list(sharp_childstr), length=objective_TSP(traceStr2list(sharp_childstr))))
                    
                    else:
                        print("!!! Fail mutation process")

        
        print("------------------------------------------------------------------------------")
    
    Pool = updatePool(Pool, Pool_sharp, N)

    best_now = Pool[N-1].length

    print(f"END generation: {g}, best solution now is: {best_now}")
    
    print("#######################################################################################")
    
    g += 1


print(best_now)
# Out:
# got update!
# 1th pairs of parents in generation 1:
# parent_1: Individual(trace=[6, 8, 7, 5, 9, 13, 2, 1, 11, 12, 10, 14, 3, 4], length=6555.0), parent_2: Individual(trace=[9, 12, 1, 14, 3, 6, 5, 8, 7, 4, 2, 11, 10, 13], length=6483.0)
# ------------------------------------------------------------------------------
# 2th pairs of parents in generation 1:
# parent_1: Individual(trace=[1, 13, 4, 3, 14, 7, 11, 10, 5, 6, 8, 12, 9, 2], length=6097.0), parent_2: Individual(trace=[9, 12, 1, 14, 3, 6, 5, 8, 7, 4, 2, 11, 10, 13], length=6483.0)
# spent_time for this request: 4.966710567474365
# crossover of 2th parents in generation 1
# child1 accepted!
# child2 accepted!
# time for muatating: 2.4581520557403564
# time for muatating: 2.401024103164673
# ------------------------------------------------------------------------------
# 3th pairs of parents in generation 1:
# parent_1: Individual(trace=[14, 8, 3, 2, 12, 5, 13, 11, 4, 6, 7, 10, 1, 9], length=6527.0), parent_2: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0)
# ------------------------------------------------------------------------------
# 4th pairs of parents in generation 1:
# parent_1: Individual(trace=[14, 5, 13, 9, 12, 4, 11, 3, 2, 8, 10, 6, 7, 1], length=7049.0), parent_2: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0)
# ------------------------------------------------------------------------------
# 5th pairs of parents in generation 1:
# parent_1: Individual(trace=[10, 1, 2, 6, 9, 13, 12, 14, 3, 11, 5, 4, 7, 8], length=6186.0), parent_2: Individual(trace=[13, 1, 9, 5, 14, 2, 10, 4, 3, 6, 12, 7, 11, 8], length=6117.0)
# ------------------------------------------------------------------------------
# 6th pairs of parents in generation 1:
# parent_1: Individual(trace=[7, 4, 9, 10, 1, 11, 3, 6, 14, 13, 5, 2, 12, 8], length=6762.0), parent_2: Individual(trace=[6, 12, 10, 4, 3, 11, 14, 8, 9, 13, 5, 7, 1, 2], length=6900.0)
# spent_time for this request: 3.7181451320648193
# crossover of 6th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 7th pairs of parents in generation 1:
# parent_1: Individual(trace=[7, 4, 9, 10, 1, 11, 3, 6, 14, 13, 5, 2, 12, 8], length=6762.0), parent_2: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0)
# ------------------------------------------------------------------------------
# 8th pairs of parents in generation 1:
# parent_1: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0), parent_2: Individual(trace=[13, 1, 9, 5, 14, 2, 10, 4, 3, 6, 12, 7, 11, 8], length=6117.0)
# ------------------------------------------------------------------------------
# 9th pairs of parents in generation 1:
# parent_1: Individual(trace=[2, 1, 9, 13, 14, 6, 8, 7, 5, 12, 3, 11, 10, 4], length=6247.0), parent_2: Individual(trace=[1, 11, 9, 8, 12, 2, 10, 5, 14, 4, 13, 7, 3, 6], length=6152.0)
# spent_time for this request: 3.673128604888916
# crossover of 9th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 10th pairs of parents in generation 1:
# parent_1: Individual(trace=[1, 11, 9, 8, 12, 2, 10, 5, 14, 4, 13, 7, 3, 6], length=6152.0), parent_2: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0)
# ------------------------------------------------------------------------------
# 11th pairs of parents in generation 1:
# parent_1: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0), parent_2: Individual(trace=[1, 13, 4, 3, 14, 7, 11, 10, 5, 6, 8, 12, 9, 2], length=6097.0)
# spent_time for this request: 3.67192006111145
# crossover of 11th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 12th pairs of parents in generation 1:
# parent_1: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0), parent_2: Individual(trace=[11, 12, 8, 9, 3, 7, 1, 13, 14, 6, 5, 4, 10, 2], length=6565.0)
# spent_time for this request: 3.925037145614624
# crossover of 12th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 13th pairs of parents in generation 1:
# parent_1: Individual(trace=[2, 10, 6, 12, 9, 13, 7, 1, 4, 8, 5, 14, 3, 11], length=7210.0), parent_2: Individual(trace=[3, 8, 7, 12, 4, 14, 11, 9, 5, 1, 13, 2, 10, 6], length=6798.0)
# spent_time for this request: 4.084495306015015
# crossover of 13th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 14th pairs of parents in generation 1:
# parent_1: Individual(trace=[1, 13, 4, 3, 14, 7, 11, 10, 5, 6, 8, 12, 9, 2], length=6097.0), parent_2: Individual(trace=[6, 8, 7, 5, 9, 13, 2, 1, 11, 12, 10, 14, 3, 4], length=6555.0)
# spent_time for this request: 3.7054173946380615
# crossover of 14th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 15th pairs of parents in generation 1:
# parent_1: Individual(trace=[2, 1, 9, 13, 14, 6, 8, 7, 5, 12, 3, 11, 10, 4], length=6247.0), parent_2: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0)
# spent_time for this request: 3.675778865814209
# crossover of 15th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 16th pairs of parents in generation 1:
# parent_1: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0), parent_2: Individual(trace=[10, 1, 2, 6, 9, 13, 12, 14, 3, 11, 5, 4, 7, 8], length=6186.0)
# ------------------------------------------------------------------------------
# 17th pairs of parents in generation 1:
# parent_1: Individual(trace=[14, 8, 3, 2, 12, 5, 13, 11, 4, 6, 7, 10, 1, 9], length=6527.0), parent_2: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0)
# spent_time for this request: 3.7104218006134033
# crossover of 17th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 18th pairs of parents in generation 1:
# parent_1: Individual(trace=[1, 13, 4, 3, 14, 7, 11, 10, 5, 6, 8, 12, 9, 2], length=6097.0), parent_2: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0)
# spent_time for this request: 3.7761051654815674
# crossover of 18th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 19th pairs of parents in generation 1:
# parent_1: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0), parent_2: Individual(trace=[7, 4, 1, 10, 6, 5, 11, 8, 14, 9, 3, 13, 2, 12], length=7253.0)
# spent_time for this request: 3.7729604244232178
# crossover of 19th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 20th pairs of parents in generation 1:
# parent_1: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0), parent_2: Individual(trace=[10, 1, 2, 6, 9, 13, 12, 14, 3, 11, 5, 4, 7, 8], length=6186.0)
# ------------------------------------------------------------------------------
# 21th pairs of parents in generation 1:
# parent_1: Individual(trace=[10, 1, 2, 6, 9, 13, 12, 14, 3, 11, 5, 4, 7, 8], length=6186.0), parent_2: Individual(trace=[13, 1, 9, 5, 14, 2, 10, 4, 3, 6, 12, 7, 11, 8], length=6117.0)
# ------------------------------------------------------------------------------
# 22th pairs of parents in generation 1:
# parent_1: Individual(trace=[4, 5, 13, 7, 11, 6, 8, 9, 10, 3, 1, 12, 2, 14], length=6528.0), parent_2: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0)
# spent_time for this request: 3.8372933864593506
# crossover of 22th parents in generation 1
# ------------------------------------------------------------------------------
# 23th pairs of parents in generation 1:
# parent_1: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0), parent_2: Individual(trace=[3, 8, 7, 12, 4, 14, 11, 9, 5, 1, 13, 2, 10, 6], length=6798.0)
# ------------------------------------------------------------------------------
# 24th pairs of parents in generation 1:
# parent_1: Individual(trace=[1, 11, 9, 8, 12, 2, 10, 5, 14, 4, 13, 7, 3, 6], length=6152.0), parent_2: Individual(trace=[14, 8, 3, 2, 12, 5, 13, 11, 4, 6, 7, 10, 1, 9], length=6527.0)
# spent_time for this request: 3.723430871963501
# crossover of 24th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 25th pairs of parents in generation 1:
# parent_1: Individual(trace=[3, 8, 7, 12, 4, 14, 11, 9, 5, 1, 13, 2, 10, 6], length=6798.0), parent_2: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0)
# spent_time for this request: 3.7759222984313965
# crossover of 25th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 26th pairs of parents in generation 1:
# parent_1: Individual(trace=[14, 5, 13, 9, 12, 4, 11, 3, 2, 8, 10, 6, 7, 1], length=7049.0), parent_2: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0)
# spent_time for this request: 4.294353246688843
# crossover of 26th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 27th pairs of parents in generation 1:
# parent_1: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0), parent_2: Individual(trace=[10, 1, 2, 6, 9, 13, 12, 14, 3, 11, 5, 4, 7, 8], length=6186.0)
# spent_time for this request: 4.287742614746094
# crossover of 27th parents in generation 1
# child1 accepted!
# ------------------------------------------------------------------------------
# 28th pairs of parents in generation 1:
# parent_1: Individual(trace=[4, 5, 13, 7, 11, 6, 8, 9, 10, 3, 1, 12, 2, 14], length=6528.0), parent_2: Individual(trace=[10, 1, 2, 6, 9, 13, 12, 14, 3, 11, 5, 4, 7, 8], length=6186.0)
# ------------------------------------------------------------------------------
# 29th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 12, 1, 14, 3, 6, 5, 8, 7, 4, 2, 11, 10, 13], length=6483.0), parent_2: Individual(trace=[6, 3, 4, 2, 5, 8, 13, 14, 1, 12, 10, 11, 7, 9], length=7566.0)
# ------------------------------------------------------------------------------
# 30th pairs of parents in generation 1:
# parent_1: Individual(trace=[13, 1, 9, 5, 14, 2, 10, 4, 3, 6, 12, 7, 11, 8], length=6117.0), parent_2: Individual(trace=[4, 5, 13, 7, 11, 6, 8, 9, 10, 3, 1, 12, 2, 14], length=6528.0)
# spent_time for this request: 4.245419025421143
# crossover of 30th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 31th pairs of parents in generation 1:
# parent_1: Individual(trace=[13, 1, 9, 5, 14, 2, 10, 4, 3, 6, 12, 7, 11, 8], length=6117.0), parent_2: Individual(trace=[14, 8, 3, 2, 12, 5, 13, 11, 4, 6, 7, 10, 1, 9], length=6527.0)
# spent_time for this request: 3.880702495574951
# crossover of 31th parents in generation 1
# ------------------------------------------------------------------------------
# 32th pairs of parents in generation 1:
# parent_1: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0), parent_2: Individual(trace=[9, 10, 12, 13, 6, 11, 4, 3, 1, 14, 5, 8, 2, 7], length=7222.0)
# spent_time for this request: 3.8288958072662354
# crossover of 32th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 33th pairs of parents in generation 1:
# parent_1: Individual(trace=[14, 8, 3, 2, 12, 5, 13, 11, 4, 6, 7, 10, 1, 9], length=6527.0), parent_2: Individual(trace=[1, 13, 4, 3, 14, 7, 11, 10, 5, 6, 8, 12, 9, 2], length=6097.0)
# spent_time for this request: 4.017376899719238
# crossover of 33th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 34th pairs of parents in generation 1:
# parent_1: Individual(trace=[14, 8, 3, 2, 12, 5, 13, 11, 4, 6, 7, 10, 1, 9], length=6527.0), parent_2: Individual(trace=[11, 12, 8, 9, 3, 7, 1, 13, 14, 6, 5, 4, 10, 2], length=6565.0)
# spent_time for this request: 3.706003427505493
# crossover of 34th parents in generation 1
# child1 accepted!
# time for muatating: 2.445521831512451
# time for muatating: 2.48934268951416
# !!! Fail mutation process
# ------------------------------------------------------------------------------
# 35th pairs of parents in generation 1:
# parent_1: Individual(trace=[1, 13, 4, 3, 14, 7, 11, 10, 5, 6, 8, 12, 9, 2], length=6097.0), parent_2: Individual(trace=[1, 11, 9, 8, 12, 2, 10, 5, 14, 4, 13, 7, 3, 6], length=6152.0)
# spent_time for this request: 3.6558921337127686
# crossover of 35th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 36th pairs of parents in generation 1:
# parent_1: Individual(trace=[1, 11, 9, 8, 12, 2, 10, 5, 14, 4, 13, 7, 3, 6], length=6152.0), parent_2: Individual(trace=[13, 1, 9, 5, 14, 2, 10, 4, 3, 6, 12, 7, 11, 8], length=6117.0)
# spent_time for this request: 3.6795084476470947
# crossover of 36th parents in generation 1
# child1 accepted!
# ------------------------------------------------------------------------------
# 37th pairs of parents in generation 1:
# parent_1: Individual(trace=[2, 1, 9, 13, 14, 6, 8, 7, 5, 12, 3, 11, 10, 4], length=6247.0), parent_2: Individual(trace=[9, 12, 1, 14, 3, 6, 5, 8, 7, 4, 2, 11, 10, 13], length=6483.0)
# spent_time for this request: 4.232393264770508
# crossover of 37th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 38th pairs of parents in generation 1:
# parent_1: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0), parent_2: Individual(trace=[9, 10, 12, 13, 6, 11, 4, 3, 1, 14, 5, 8, 2, 7], length=7222.0)
# ------------------------------------------------------------------------------
# 39th pairs of parents in generation 1:
# parent_1: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0), parent_2: Individual(trace=[2, 1, 9, 13, 14, 6, 8, 7, 5, 12, 3, 11, 10, 4], length=6247.0)
# spent_time for this request: 3.761723279953003
# crossover of 39th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 40th pairs of parents in generation 1:
# parent_1: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0), parent_2: Individual(trace=[13, 1, 9, 5, 14, 2, 10, 4, 3, 6, 12, 7, 11, 8], length=6117.0)
# spent_time for this request: 3.6778268814086914
# crossover of 40th parents in generation 1
# child1 accepted!
# child2 accepted!
# time for muatating: 2.538328170776367
# time for muatating: 2.3485910892486572
# ------------------------------------------------------------------------------
# END generation: 1, best solution now is: 5296.0
# #######################################################################################
# got update!
# 1th pairs of parents in generation 2:
# parent_1: Individual(trace=[6, 12, 10, 11, 3, 2, 1, 8, 9, 13, 5, 14, 4, 7], length=5296.0), parent_2: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0)
# ------------------------------------------------------------------------------
# 2th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 12, 2, 1, 4, 8, 11, 9, 10, 13, 7, 14, 6], length=5369.0), parent_2: Individual(trace=[2, 10, 5, 14, 4, 3, 6, 12, 7, 11, 8, 1, 13, 9], length=5531.0)
# ------------------------------------------------------------------------------
# 3th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 12, 2, 1, 4, 8, 11, 9, 10, 13, 7, 14, 6], length=5369.0), parent_2: Individual(trace=[6, 12, 10, 11, 3, 2, 1, 8, 9, 13, 5, 14, 4, 7], length=5296.0)
# spent_time for this request: 4.001957416534424
# crossover of 3th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 2.510230541229248
# time for muatating: 2.482208251953125
# ------------------------------------------------------------------------------
# 4th pairs of parents in generation 2:
# parent_1: Individual(trace=[6, 12, 10, 11, 3, 2, 1, 8, 9, 13, 5, 14, 4, 7], length=5296.0), parent_2: Individual(trace=[1, 4, 2, 3, 5, 11, 8, 9, 10, 13, 12, 6, 14, 7], length=6292.0)
# spent_time for this request: 3.712357521057129
# crossover of 4th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 5th pairs of parents in generation 2:
# parent_1: Individual(trace=[3, 2, 11, 8, 4, 12, 1, 13, 9, 10, 6, 5, 7, 14], length=5663.0), parent_2: Individual(trace=[5, 3, 12, 2, 14, 1, 10, 4, 8, 9, 11, 13, 6, 7], length=6078.0)
# spent_time for this request: 3.7955636978149414
# crossover of 5th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 6th pairs of parents in generation 2:
# parent_1: Individual(trace=[1, 13, 14, 6, 5, 4, 10, 2, 12, 11, 8, 9, 3, 7], length=6472.0), parent_2: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0)
# spent_time for this request: 4.064191818237305
# crossover of 6th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 7th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0), parent_2: Individual(trace=[5, 3, 12, 2, 14, 1, 10, 4, 8, 9, 11, 13, 6, 7], length=6078.0)
# ------------------------------------------------------------------------------
# 8th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0), parent_2: Individual(trace=[4, 13, 8, 11, 2, 10, 14, 6, 5, 7, 12, 3, 1, 9], length=5784.0)
# spent_time for this request: 3.952502965927124
# crossover of 8th parents in generation 2
# ------------------------------------------------------------------------------
# 9th pairs of parents in generation 2:
# parent_1: Individual(trace=[1, 13, 4, 12, 3, 2, 8, 9, 10, 6, 5, 11, 7, 14], length=6077.0), parent_2: Individual(trace=[11, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1, 8], length=5716.0)
# ------------------------------------------------------------------------------
# 10th pairs of parents in generation 2:
# parent_1: Individual(trace=[14, 1, 13, 2, 9, 8, 11, 3, 10, 12, 6, 7, 4, 5], length=6178.0), parent_2: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0)
# ------------------------------------------------------------------------------
# 11th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 2, 14, 12, 1, 4, 8, 9, 11, 13, 10, 7, 6], length=6191.0), parent_2: Individual(trace=[11, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1, 8], length=5716.0)
# spent_time for this request: 3.7237162590026855
# crossover of 11th parents in generation 2
# child1 accepted!
# time for muatating: 2.6326205730438232
# time for muatating: 2.6116325855255127
# !!! Fail mutation process
# ------------------------------------------------------------------------------
# 12th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0), parent_2: Individual(trace=[2, 10, 5, 14, 4, 3, 6, 12, 7, 11, 8, 1, 13, 9], length=5531.0)
# spent_time for this request: 3.635340452194214
# crossover of 12th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 2.4413328170776367
# time for muatating: 2.5299205780029297
# ------------------------------------------------------------------------------
# 13th pairs of parents in generation 2:
# parent_1: Individual(trace=[1, 13, 4, 12, 3, 2, 8, 9, 10, 6, 5, 11, 7, 14], length=6077.0), parent_2: Individual(trace=[13, 8, 4, 12, 3, 2, 11, 9, 10, 6, 5, 7, 14, 1], length=5492.0)
# ------------------------------------------------------------------------------
# 14th pairs of parents in generation 2:
# parent_1: Individual(trace=[1, 11, 9, 8, 12, 4, 10, 5, 14, 3, 13, 7, 6, 2], length=5819.0), parent_2: Individual(trace=[2, 10, 5, 14, 4, 3, 6, 12, 7, 11, 8, 1, 13, 9], length=5531.0)
# spent_time for this request: 3.9654335975646973
# crossover of 14th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 2.4392616748809814
# time for muatating: 2.8347082138061523
# ------------------------------------------------------------------------------
# 15th pairs of parents in generation 2:
# parent_1: Individual(trace=[2, 10, 5, 14, 4, 3, 6, 12, 7, 11, 8, 1, 13, 9], length=5531.0), parent_2: Individual(trace=[14, 1, 13, 2, 9, 8, 11, 3, 10, 12, 6, 7, 4, 5], length=6178.0)
# spent_time for this request: 3.8708977699279785
# crossover of 15th parents in generation 2
# child1 accepted!
# ------------------------------------------------------------------------------
# 16th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 12, 2, 1, 4, 8, 11, 9, 10, 13, 7, 14, 6], length=5369.0), parent_2: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0)
# spent_time for this request: 3.9860622882843018
# crossover of 16th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 2.4858603477478027
# time for muatating: 2.5706660747528076
# ------------------------------------------------------------------------------
# 17th pairs of parents in generation 2:
# parent_1: Individual(trace=[4, 13, 8, 11, 2, 10, 14, 6, 5, 7, 12, 3, 1, 9], length=5784.0), parent_2: Individual(trace=[2, 10, 5, 14, 4, 3, 6, 12, 7, 11, 8, 1, 13, 9], length=5531.0)
# spent_time for this request: 4.3355653285980225
# crossover of 17th parents in generation 2
# ------------------------------------------------------------------------------
# 18th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 12, 2, 1, 4, 8, 11, 9, 10, 13, 7, 14, 6], length=5369.0), parent_2: Individual(trace=[5, 14, 2, 10, 4, 3, 6, 12, 7, 11, 8, 9, 13, 1], length=6172.0)
# spent_time for this request: 3.8885316848754883
# crossover of 18th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 19th pairs of parents in generation 2:
# parent_1: Individual(trace=[4, 13, 8, 11, 2, 10, 14, 6, 5, 7, 12, 3, 1, 9], length=5784.0), parent_2: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0)
# ------------------------------------------------------------------------------
# 20th pairs of parents in generation 2:
# parent_1: Individual(trace=[2, 10, 5, 14, 4, 3, 6, 12, 7, 11, 8, 1, 13, 9], length=5531.0), parent_2: Individual(trace=[5, 3, 12, 2, 1, 4, 8, 11, 9, 10, 13, 7, 14, 6], length=5369.0)
# spent_time for this request: 3.6923465728759766
# crossover of 20th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 21th pairs of parents in generation 2:
# parent_1: Individual(trace=[2, 10, 5, 14, 4, 3, 6, 12, 7, 11, 8, 1, 13, 9], length=5531.0), parent_2: Individual(trace=[11, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1, 8], length=5716.0)
# spent_time for this request: 3.9300949573516846
# crossover of 21th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 2.2945215702056885
# time for muatating: 2.7303481101989746
# ------------------------------------------------------------------------------
# 22th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 12, 2, 1, 4, 8, 11, 9, 10, 13, 7, 14, 6], length=5369.0), parent_2: Individual(trace=[13, 8, 4, 12, 3, 2, 11, 9, 10, 6, 5, 7, 14, 1], length=5492.0)
# spent_time for this request: 3.990666389465332
# crossover of 22th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 2.426050901412964
# time for muatating: 2.467351198196411
# ------------------------------------------------------------------------------
# 23th pairs of parents in generation 2:
# parent_1: Individual(trace=[2, 10, 5, 14, 4, 3, 6, 12, 7, 11, 8, 1, 13, 9], length=5531.0), parent_2: Individual(trace=[6, 12, 10, 11, 3, 2, 1, 8, 9, 13, 5, 14, 4, 7], length=5296.0)
# spent_time for this request: 3.9130024909973145
# crossover of 23th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 2.351102352142334
# time for muatating: 2.524895191192627
# ------------------------------------------------------------------------------
# 24th pairs of parents in generation 2:
# parent_1: Individual(trace=[6, 12, 10, 11, 3, 2, 1, 8, 9, 13, 5, 14, 4, 7], length=5296.0), parent_2: Individual(trace=[1, 11, 9, 8, 12, 2, 10, 5, 14, 4, 13, 7, 3, 6], length=6152.0)
# spent_time for this request: 3.8005027770996094
# crossover of 24th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 25th pairs of parents in generation 2:
# parent_1: Individual(trace=[11, 8, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1], length=5648.0), parent_2: Individual(trace=[10, 1, 2, 6, 9, 13, 12, 14, 3, 11, 5, 4, 7, 8], length=6186.0)
# ------------------------------------------------------------------------------
# 26th pairs of parents in generation 2:
# parent_1: Individual(trace=[11, 4, 12, 3, 2, 13, 9, 10, 6, 5, 7, 14, 1, 8], length=5716.0), parent_2: Individual(trace=[1, 13, 4, 3, 14, 7, 11, 10, 5, 6, 8, 12, 9, 2], length=6097.0)
# spent_time for this request: 3.70530366897583
# crossover of 26th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 27th pairs of parents in generation 2:
# parent_1: Individual(trace=[13, 8, 4, 12, 3, 2, 11, 9, 10, 6, 5, 7, 14, 1], length=5492.0), parent_2: Individual(trace=[1, 11, 9, 8, 12, 2, 10, 5, 14, 4, 13, 7, 3, 6], length=6152.0)
# spent_time for this request: 3.8349127769470215
# crossover of 27th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 28th pairs of parents in generation 2:
# parent_1: Individual(trace=[6, 12, 10, 11, 3, 2, 1, 8, 9, 13, 5, 14, 4, 7], length=5296.0), parent_2: Individual(trace=[5, 3, 12, 2, 1, 4, 8, 11, 9, 10, 13, 7, 14, 6], length=5369.0)
# spent_time for this request: 4.600817918777466
# crossover of 28th parents in generation 2
# ------------------------------------------------------------------------------
# 29th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0), parent_2: Individual(trace=[1, 13, 4, 12, 3, 2, 8, 9, 10, 6, 5, 11, 7, 14], length=6077.0)
# ------------------------------------------------------------------------------
# 30th pairs of parents in generation 2:
# parent_1: Individual(trace=[2, 1, 9, 13, 14, 6, 8, 7, 5, 12, 3, 11, 10, 4], length=6247.0), parent_2: Individual(trace=[14, 8, 4, 10, 11, 9, 7, 6, 12, 5, 13, 2, 3, 1], length=6185.0)
# spent_time for this request: 3.984084367752075
# crossover of 30th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 31th pairs of parents in generation 2:
# parent_1: Individual(trace=[1, 13, 4, 12, 3, 2, 8, 9, 10, 6, 5, 11, 7, 14], length=6077.0), parent_2: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0)
# spent_time for this request: 4.1118903160095215
# crossover of 31th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 32th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0), parent_2: Individual(trace=[5, 3, 12, 2, 1, 4, 8, 11, 9, 10, 13, 7, 14, 6], length=5369.0)
# spent_time for this request: 3.844127893447876
# crossover of 32th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 2.355389356613159
# time for muatating: 2.347888469696045
# ------------------------------------------------------------------------------
# 33th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 12, 2, 1, 4, 8, 11, 9, 10, 13, 7, 14, 6], length=5369.0), parent_2: Individual(trace=[6, 12, 10, 11, 3, 2, 1, 8, 9, 13, 5, 14, 4, 7], length=5296.0)
# spent_time for this request: 4.008354425430298
# crossover of 33th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 34th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0), parent_2: Individual(trace=[5, 3, 12, 2, 14, 1, 10, 4, 8, 9, 11, 13, 6, 7], length=6078.0)
# spent_time for this request: 3.9473068714141846
# crossover of 34th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 35th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 12, 2, 14, 1, 8, 4, 10, 11, 9, 13, 7, 6], length=5563.0), parent_2: Individual(trace=[6, 12, 10, 11, 3, 2, 1, 8, 9, 13, 5, 14, 4, 7], length=5296.0)
# spent_time for this request: 3.7671165466308594
# crossover of 35th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 36th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 3, 12, 2, 1, 4, 8, 11, 9, 10, 13, 7, 14, 6], length=5369.0), parent_2: Individual(trace=[6, 12, 10, 11, 3, 2, 1, 8, 9, 13, 5, 14, 4, 7], length=5296.0)
# spent_time for this request: 3.655468463897705
# crossover of 36th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 37th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 14, 2, 10, 4, 3, 6, 12, 7, 11, 8, 9, 13, 1], length=6172.0), parent_2: Individual(trace=[5, 3, 12, 2, 1, 4, 8, 11, 9, 10, 13, 7, 14, 6], length=5369.0)
# spent_time for this request: 4.136206388473511
# crossover of 37th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 38th pairs of parents in generation 2:
# parent_1: Individual(trace=[6, 12, 10, 11, 3, 2, 1, 8, 9, 13, 5, 14, 4, 7], length=5296.0), parent_2: Individual(trace=[3, 2, 11, 8, 4, 12, 1, 13, 9, 10, 6, 5, 7, 14], length=5663.0)
# spent_time for this request: 3.8751187324523926
# crossover of 38th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 2.3808159828186035
# time for muatating: 2.314431667327881
# ------------------------------------------------------------------------------
# 39th pairs of parents in generation 2:
# parent_1: Individual(trace=[6, 12, 10, 11, 3, 2, 1, 8, 9, 13, 5, 14, 4, 7], length=5296.0), parent_2: Individual(trace=[2, 10, 5, 14, 4, 3, 6, 12, 7, 11, 8, 1, 13, 9], length=5531.0)
# spent_time for this request: 3.795729637145996
# crossover of 39th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 40th pairs of parents in generation 2:
# parent_1: Individual(trace=[6, 12, 10, 11, 3, 2, 1, 8, 9, 13, 5, 14, 4, 7], length=5296.0), parent_2: Individual(trace=[2, 10, 5, 14, 4, 3, 6, 12, 7, 11, 8, 1, 13, 9], length=5531.0)
# spent_time for this request: 3.9192445278167725
# crossover of 40th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 2.3705344200134277
# time for muatating: 2.7486677169799805
# ------------------------------------------------------------------------------
# END generation: 2, best solution now is: 4426.0
# #######################################################################################
# got update!
# 1th pairs of parents in generation 3:
# parent_1: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0), parent_2: Individual(trace=[12, 3, 6, 5, 4, 14, 10, 1, 2, 13, 11, 8, 9, 7], length=5092.0)
# spent_time for this request: 3.6781857013702393
# crossover of 1th parents in generation 3
# child1 accepted!
# child2 accepted!
# time for muatating: 2.282304048538208
# time for muatating: 2.9555470943450928
# ------------------------------------------------------------------------------
# 2th pairs of parents in generation 3:
# parent_1: Individual(trace=[6, 12, 5, 14, 7, 10, 11, 13, 9, 8, 1, 2, 3, 4], length=4764.0), parent_2: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0)
# spent_time for this request: 3.8813464641571045
# crossover of 2th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 3th pairs of parents in generation 3:
# parent_1: Individual(trace=[6, 12, 5, 14, 4, 3, 2, 1, 8, 9, 13, 11, 10, 7], length=4654.0), parent_2: Individual(trace=[5, 3, 12, 14, 13, 7, 6, 4, 2, 8, 9, 11, 10, 1], length=4795.0)
# spent_time for this request: 3.7357544898986816
# crossover of 3th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 4th pairs of parents in generation 3:
# parent_1: Individual(trace=[3, 2, 10, 11, 1, 8, 13, 12, 9, 6, 5, 14, 4, 7], length=5438.0), parent_2: Individual(trace=[5, 14, 6, 12, 7, 10, 8, 9, 11, 1, 3, 4, 13, 2], length=5558.0)
# ------------------------------------------------------------------------------
# 5th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 11, 9, 8, 6, 12, 7, 14, 4, 3, 13, 5, 10, 2], length=5134.0), parent_2: Individual(trace=[5, 3, 12, 14, 13, 7, 6, 4, 2, 8, 9, 11, 10, 1], length=4795.0)
# spent_time for this request: 3.7286300659179688
# crossover of 5th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 6th pairs of parents in generation 3:
# parent_1: Individual(trace=[6, 12, 5, 14, 4, 3, 2, 1, 8, 9, 13, 11, 10, 7], length=4654.0), parent_2: Individual(trace=[5, 3, 12, 2, 14, 13, 7, 6, 4, 11, 9, 10, 1, 8], length=5360.0)
# spent_time for this request: 3.8743743896484375
# crossover of 6th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 7th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 8, 4, 10, 11, 9, 13, 7, 14, 6, 5, 3, 12, 2], length=5323.0), parent_2: Individual(trace=[5, 4, 2, 1, 8, 14, 11, 9, 10, 3, 7, 13, 12, 6], length=4983.0)
# ------------------------------------------------------------------------------
# 8th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 3, 12, 2, 14, 13, 7, 6, 4, 11, 9, 10, 1, 8], length=5360.0), parent_2: Individual(trace=[12, 3, 6, 5, 4, 14, 10, 1, 2, 13, 11, 8, 9, 7], length=5092.0)
# spent_time for this request: 3.650672435760498
# crossover of 8th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 9th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 3, 12, 2, 14, 13, 7, 6, 4, 11, 9, 10, 1, 8], length=5360.0), parent_2: Individual(trace=[6, 12, 5, 14, 7, 10, 11, 13, 9, 8, 1, 2, 3, 4], length=4764.0)
# ------------------------------------------------------------------------------
# 10th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 11, 9, 8, 6, 12, 7, 14, 4, 3, 13, 5, 10, 2], length=5134.0), parent_2: Individual(trace=[6, 13, 10, 9, 11, 2, 8, 12, 3, 14, 7, 1, 5, 4], length=5215.0)
# spent_time for this request: 3.648601770401001
# crossover of 10th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 11th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 4, 2, 1, 8, 14, 11, 9, 10, 3, 7, 13, 12, 6], length=4983.0), parent_2: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0)
# spent_time for this request: 3.7008697986602783
# crossover of 11th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 12th pairs of parents in generation 3:
# parent_1: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0), parent_2: Individual(trace=[5, 3, 12, 14, 13, 7, 6, 4, 2, 8, 9, 11, 10, 1], length=4795.0)
# spent_time for this request: 3.6492786407470703
# crossover of 12th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 13th pairs of parents in generation 3:
# parent_1: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0), parent_2: Individual(trace=[5, 3, 12, 2, 14, 13, 7, 6, 4, 11, 9, 10, 1, 8], length=5360.0)
# spent_time for this request: 3.75323224067688
# crossover of 13th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 14th pairs of parents in generation 3:
# parent_1: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0), parent_2: Individual(trace=[6, 12, 3, 2, 1, 8, 4, 10, 11, 9, 13, 5, 14, 7], length=5283.0)
# ------------------------------------------------------------------------------
# 15th pairs of parents in generation 3:
# parent_1: Individual(trace=[6, 13, 10, 9, 11, 2, 8, 12, 3, 14, 7, 1, 5, 4], length=5215.0), parent_2: Individual(trace=[6, 12, 5, 14, 4, 3, 2, 1, 8, 9, 13, 11, 10, 7], length=4654.0)
# ------------------------------------------------------------------------------
# 16th pairs of parents in generation 3:
# parent_1: Individual(trace=[6, 12, 10, 11, 3, 2, 1, 8, 9, 13, 5, 14, 4, 7], length=5296.0), parent_2: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0)
# ------------------------------------------------------------------------------
# 17th pairs of parents in generation 3:
# parent_1: Individual(trace=[7, 3, 12, 2, 1, 11, 8, 9, 10, 13, 5, 14, 4, 6], length=4925.0), parent_2: Individual(trace=[13, 8, 4, 12, 3, 2, 11, 9, 10, 6, 5, 7, 14, 1], length=5492.0)
# spent_time for this request: 4.4050657749176025
# crossover of 17th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 18th pairs of parents in generation 3:
# parent_1: Individual(trace=[7, 3, 12, 2, 1, 11, 8, 9, 10, 13, 5, 14, 4, 6], length=4925.0), parent_2: Individual(trace=[6, 12, 5, 14, 7, 10, 11, 13, 9, 8, 1, 2, 3, 4], length=4764.0)
# spent_time for this request: 3.874037265777588
# crossover of 18th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 19th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 11, 9, 8, 6, 12, 7, 14, 4, 3, 13, 5, 10, 2], length=5134.0), parent_2: Individual(trace=[6, 12, 3, 2, 1, 8, 4, 10, 11, 9, 13, 5, 14, 7], length=5283.0)
# spent_time for this request: 3.9167144298553467
# crossover of 19th parents in generation 3
# child1 accepted!
# child2 accepted!
# time for muatating: 2.5013320446014404
# time for muatating: 2.4666290283203125
# ------------------------------------------------------------------------------
# 20th pairs of parents in generation 3:
# parent_1: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0), parent_2: Individual(trace=[5, 4, 2, 1, 8, 14, 11, 9, 10, 3, 7, 13, 12, 6], length=4983.0)
# spent_time for this request: 3.6789321899414062
# crossover of 20th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 21th pairs of parents in generation 3:
# parent_1: Individual(trace=[12, 3, 6, 5, 4, 14, 10, 1, 2, 13, 11, 8, 9, 7], length=5092.0), parent_2: Individual(trace=[5, 3, 12, 14, 13, 7, 6, 4, 2, 8, 9, 11, 10, 1], length=4795.0)
# ------------------------------------------------------------------------------
# 22th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 3, 12, 14, 13, 7, 6, 4, 2, 8, 9, 11, 10, 1], length=4795.0), parent_2: Individual(trace=[7, 3, 12, 2, 1, 11, 8, 9, 10, 13, 5, 14, 4, 6], length=4925.0)
# spent_time for this request: 3.899731159210205
# crossover of 22th parents in generation 3
# child1 accepted!
# ------------------------------------------------------------------------------
# 23th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 4, 2, 1, 8, 14, 11, 9, 10, 3, 7, 13, 12, 6], length=4983.0), parent_2: Individual(trace=[12, 3, 6, 5, 4, 14, 10, 1, 2, 13, 11, 8, 9, 7], length=5092.0)
# spent_time for this request: 4.187678098678589
# crossover of 23th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 24th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 3, 12, 2, 1, 4, 8, 11, 9, 10, 13, 7, 14, 6], length=5369.0), parent_2: Individual(trace=[1, 11, 9, 8, 6, 12, 7, 14, 4, 3, 13, 5, 10, 2], length=5134.0)
# ------------------------------------------------------------------------------
# 25th pairs of parents in generation 3:
# parent_1: Individual(trace=[6, 13, 10, 9, 11, 2, 8, 12, 3, 14, 7, 1, 5, 4], length=5215.0), parent_2: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0)
# spent_time for this request: 3.829050064086914
# crossover of 25th parents in generation 3
# child1 accepted!
# ------------------------------------------------------------------------------
# 26th pairs of parents in generation 3:
# parent_1: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0), parent_2: Individual(trace=[7, 3, 12, 2, 1, 11, 8, 9, 10, 13, 5, 14, 4, 6], length=4925.0)
# spent_time for this request: 3.7540645599365234
# crossover of 26th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 27th pairs of parents in generation 3:
# parent_1: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0), parent_2: Individual(trace=[6, 13, 10, 9, 11, 2, 8, 12, 3, 14, 7, 1, 5, 4], length=5215.0)
# spent_time for this request: 3.9928019046783447
# crossover of 27th parents in generation 3
# child2 accepted!
# time for muatating: 2.2936224937438965
# time for muatating: 2.4244003295898438
# ------------------------------------------------------------------------------
# 28th pairs of parents in generation 3:
# parent_1: Individual(trace=[6, 12, 10, 11, 3, 2, 1, 8, 9, 13, 5, 14, 4, 7], length=5296.0), parent_2: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0)
# spent_time for this request: 3.97939133644104
# crossover of 28th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 29th pairs of parents in generation 3:
# parent_1: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0), parent_2: Individual(trace=[5, 3, 12, 2, 14, 13, 7, 6, 4, 11, 9, 10, 1, 8], length=5360.0)
# spent_time for this request: 3.814361572265625
# crossover of 29th parents in generation 3
# child1 accepted!
# child2 accepted!
# time for muatating: 2.5723204612731934
# time for muatating: 2.5357747077941895
# ------------------------------------------------------------------------------
# 30th pairs of parents in generation 3:
# parent_1: Individual(trace=[6, 12, 5, 14, 4, 3, 2, 1, 8, 9, 13, 11, 10, 7], length=4654.0), parent_2: Individual(trace=[7, 3, 12, 2, 1, 11, 8, 9, 10, 13, 5, 14, 4, 6], length=4925.0)
# spent_time for this request: 3.7584383487701416
# crossover of 30th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 31th pairs of parents in generation 3:
# parent_1: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0), parent_2: Individual(trace=[11, 1, 9, 8, 6, 12, 7, 14, 4, 3, 13, 5, 10, 2], length=5425.0)
# spent_time for this request: 3.762006998062134
# crossover of 31th parents in generation 3
# ------------------------------------------------------------------------------
# 32th pairs of parents in generation 3:
# parent_1: Individual(trace=[12, 3, 6, 5, 4, 14, 10, 1, 2, 13, 11, 8, 9, 7], length=5092.0), parent_2: Individual(trace=[8, 9, 13, 5, 14, 4, 7, 6, 12, 10, 11, 3, 2, 1], length=5296.0)
# spent_time for this request: 3.770374059677124
# crossover of 32th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 33th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 3, 12, 14, 13, 7, 6, 4, 2, 8, 9, 11, 10, 1], length=4795.0), parent_2: Individual(trace=[6, 12, 3, 2, 1, 8, 4, 10, 11, 9, 13, 5, 14, 7], length=5283.0)
# spent_time for this request: 4.027416944503784
# crossover of 33th parents in generation 3
# ------------------------------------------------------------------------------
# 34th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 3, 12, 14, 13, 7, 6, 4, 2, 8, 9, 11, 10, 1], length=4795.0), parent_2: Individual(trace=[6, 12, 3, 2, 1, 8, 4, 10, 11, 9, 13, 5, 14, 7], length=5283.0)
# spent_time for this request: 3.7561838626861572
# crossover of 34th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 35th pairs of parents in generation 3:
# parent_1: Individual(trace=[6, 12, 5, 14, 7, 10, 11, 13, 9, 8, 1, 2, 3, 4], length=4764.0), parent_2: Individual(trace=[12, 3, 6, 5, 4, 14, 10, 1, 2, 13, 11, 8, 9, 7], length=5092.0)
# spent_time for this request: 3.720886468887329
# crossover of 35th parents in generation 3
# child2 accepted!
# ------------------------------------------------------------------------------
# 36th pairs of parents in generation 3:
# parent_1: Individual(trace=[6, 12, 5, 14, 7, 10, 11, 13, 9, 8, 1, 2, 3, 4], length=4764.0), parent_2: Individual(trace=[7, 3, 12, 2, 1, 11, 8, 9, 10, 13, 5, 14, 4, 6], length=4925.0)
# spent_time for this request: 3.836177110671997
# crossover of 36th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 37th pairs of parents in generation 3:
# parent_1: Individual(trace=[13, 8, 4, 12, 3, 2, 11, 9, 10, 6, 5, 7, 14, 1], length=5492.0), parent_2: Individual(trace=[6, 12, 5, 14, 4, 3, 2, 1, 8, 9, 13, 11, 10, 7], length=4654.0)
# spent_time for this request: 3.9542078971862793
# crossover of 37th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 38th pairs of parents in generation 3:
# parent_1: Individual(trace=[6, 12, 5, 14, 4, 3, 2, 1, 8, 9, 13, 11, 10, 7], length=4654.0), parent_2: Individual(trace=[12, 3, 6, 5, 4, 14, 10, 1, 2, 13, 11, 8, 9, 7], length=5092.0)
# spent_time for this request: 3.7663538455963135
# crossover of 38th parents in generation 3
# child2 accepted!
# ------------------------------------------------------------------------------
# 39th pairs of parents in generation 3:
# parent_1: Individual(trace=[12, 3, 2, 1, 8, 11, 9, 10, 13, 5, 14, 4, 7, 6], length=4426.0), parent_2: Individual(trace=[6, 12, 5, 14, 4, 3, 2, 1, 8, 9, 13, 11, 10, 7], length=4654.0)
# spent_time for this request: 3.836146354675293
# crossover of 39th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# ...
# spent_time for this request: 3.6682872772216797
# crossover of 1th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 2th pairs of parents in generation 27:
# parent_1: Individual(trace=[1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2], length=3484.0), parent_2: Individual(trace=[8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9], length=3484.0)
# spent_time for this request: 3.712092161178589
# crossover of 2th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 3th pairs of parents in generation 27:
# parent_1: Individual(trace=[6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9, 8, 13, 7], length=3484.0), parent_2: Individual(trace=[1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2], length=3484.0)
# spent_time for this request: 3.9817771911621094
# crossover of 3th parents in generation 27
# child1 accepted!
# time for muatating: 2.3348841667175293
# time for muatating: 2.4855008125305176
# !!! Fail mutation process
# ------------------------------------------------------------------------------
# 4th pairs of parents in generation 27:
# parent_1: Individual(trace=[6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9, 8, 13, 7], length=3484.0), parent_2: Individual(trace=[14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12], length=3484.0)
# spent_time for this request: 3.739283323287964
# crossover of 4th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 5th pairs of parents in generation 27:
# parent_1: Individual(trace=[11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10], length=3484.0), parent_2: Individual(trace=[2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3], length=3484.0)
# ------------------------------------------------------------------------------
# 6th pairs of parents in generation 27:
# parent_1: Individual(trace=[9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11], length=3484.0), parent_2: Individual(trace=[4, 12, 14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5], length=3484.0)
# spent_time for this request: 3.5644679069519043
# crossover of 6th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 7th pairs of parents in generation 27:
# parent_1: Individual(trace=[2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3], length=3484.0), parent_2: Individual(trace=[10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1], length=3484.0)
# ------------------------------------------------------------------------------
# 8th pairs of parents in generation 27:
# parent_1: Individual(trace=[14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12], length=3484.0), parent_2: Individual(trace=[10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1], length=3484.0)
# spent_time for this request: 3.697798013687134
# crossover of 8th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 9th pairs of parents in generation 27:
# parent_1: Individual(trace=[7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9, 8, 13], length=3484.0), parent_2: Individual(trace=[14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12], length=3484.0)
# ------------------------------------------------------------------------------
# 10th pairs of parents in generation 27:
# parent_1: Individual(trace=[11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10], length=3484.0), parent_2: Individual(trace=[1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2], length=3484.0)
# spent_time for this request: 3.735029458999634
# crossover of 10th parents in generation 27
# child1 accepted!
# child2 accepted!
# time for muatating: 2.476710319519043
# time for muatating: 2.5352389812469482
# ------------------------------------------------------------------------------
# 11th pairs of parents in generation 27:
# parent_1: Individual(trace=[10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1], length=3484.0), parent_2: Individual(trace=[14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12], length=3484.0)
# spent_time for this request: 4.1983771324157715
# crossover of 11th parents in generation 27
# child1 accepted!
# child2 accepted!
# time for muatating: 2.57200288772583
# !!! Fail mutation process
# time for muatating: 2.4617719650268555
# ------------------------------------------------------------------------------
# 12th pairs of parents in generation 27:
# parent_1: Individual(trace=[1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2], length=3484.0), parent_2: Individual(trace=[9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11], length=3484.0)
# ------------------------------------------------------------------------------
# 13th pairs of parents in generation 27:
# parent_1: Individual(trace=[14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12], length=3484.0), parent_2: Individual(trace=[10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1], length=3484.0)
# spent_time for this request: 3.898526191711426
# crossover of 13th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 14th pairs of parents in generation 27:
# parent_1: Individual(trace=[2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3], length=3484.0), parent_2: Individual(trace=[1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2], length=3484.0)
# ------------------------------------------------------------------------------
# 15th pairs of parents in generation 27:
# parent_1: Individual(trace=[12, 14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4], length=3484.0), parent_2: Individual(trace=[8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9], length=3484.0)
# ------------------------------------------------------------------------------
# 16th pairs of parents in generation 27:
# parent_1: Individual(trace=[14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12], length=3484.0), parent_2: Individual(trace=[7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9, 8, 13], length=3484.0)
# spent_time for this request: 3.735962152481079
# crossover of 16th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 17th pairs of parents in generation 27:
# parent_1: Individual(trace=[10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1], length=3484.0), parent_2: Individual(trace=[2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3], length=3484.0)
# ------------------------------------------------------------------------------
# 18th pairs of parents in generation 27:
# parent_1: Individual(trace=[3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14], length=3484.0), parent_2: Individual(trace=[10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1], length=3484.0)
# spent_time for this request: 3.6389667987823486
# crossover of 18th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 19th pairs of parents in generation 27:
# parent_1: Individual(trace=[7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9, 8, 13], length=3484.0), parent_2: Individual(trace=[12, 14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4], length=3484.0)
# spent_time for this request: 3.8399925231933594
# crossover of 19th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 20th pairs of parents in generation 27:
# parent_1: Individual(trace=[7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9, 8, 13], length=3484.0), parent_2: Individual(trace=[8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9], length=3484.0)
# spent_time for this request: 3.9259142875671387
# crossover of 20th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 21th pairs of parents in generation 27:
# parent_1: Individual(trace=[7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9, 8, 13], length=3484.0), parent_2: Individual(trace=[8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9], length=3484.0)
# ------------------------------------------------------------------------------
# 22th pairs of parents in generation 27:
# parent_1: Individual(trace=[1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2], length=3484.0), parent_2: Individual(trace=[1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2], length=3484.0)
# spent_time for this request: 3.622556209564209
# crossover of 22th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 23th pairs of parents in generation 27:
# parent_1: Individual(trace=[11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10], length=3484.0), parent_2: Individual(trace=[3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14], length=3484.0)
# spent_time for this request: 5.018164396286011
# crossover of 23th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 24th pairs of parents in generation 27:
# parent_1: Individual(trace=[1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2], length=3484.0), parent_2: Individual(trace=[11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10], length=3484.0)
# ------------------------------------------------------------------------------
# 25th pairs of parents in generation 27:
# parent_1: Individual(trace=[7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9, 8, 13], length=3484.0), parent_2: Individual(trace=[6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9, 8, 13, 7], length=3484.0)
# spent_time for this request: 3.63468599319458
# crossover of 25th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 26th pairs of parents in generation 27:
# parent_1: Individual(trace=[2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3], length=3484.0), parent_2: Individual(trace=[14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12], length=3484.0)
# spent_time for this request: 3.5989863872528076
# crossover of 26th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 27th pairs of parents in generation 27:
# parent_1: Individual(trace=[9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11], length=3484.0), parent_2: Individual(trace=[1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2], length=3484.0)
# spent_time for this request: 3.8111884593963623
# crossover of 27th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 28th pairs of parents in generation 27:
# parent_1: Individual(trace=[10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1], length=3484.0), parent_2: Individual(trace=[10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1], length=3484.0)
# spent_time for this request: 3.7076876163482666
# crossover of 28th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 29th pairs of parents in generation 27:
# parent_1: Individual(trace=[14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12], length=3484.0), parent_2: Individual(trace=[9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11], length=3484.0)
# spent_time for this request: 3.9017586708068848
# crossover of 29th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 30th pairs of parents in generation 27:
# parent_1: Individual(trace=[1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2], length=3484.0), parent_2: Individual(trace=[10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1], length=3484.0)
# ------------------------------------------------------------------------------
# 31th pairs of parents in generation 27:
# parent_1: Individual(trace=[9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11], length=3484.0), parent_2: Individual(trace=[2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3], length=3484.0)
# spent_time for this request: 3.6742913722991943
# crossover of 31th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 32th pairs of parents in generation 27:
# parent_1: Individual(trace=[2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3], length=3484.0), parent_2: Individual(trace=[1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2], length=3484.0)
# ------------------------------------------------------------------------------
# 33th pairs of parents in generation 27:
# parent_1: Individual(trace=[14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12], length=3484.0), parent_2: Individual(trace=[2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3], length=3484.0)
# spent_time for this request: 3.8004753589630127
# crossover of 33th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 34th pairs of parents in generation 27:
# parent_1: Individual(trace=[7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9, 8, 13], length=3484.0), parent_2: Individual(trace=[3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14], length=3484.0)
# spent_time for this request: 3.7705161571502686
# crossover of 34th parents in generation 27
# child1 accepted!
# child2 accepted!
# time for muatating: 2.238569974899292
# time for muatating: 2.62646746635437
# ------------------------------------------------------------------------------
# 35th pairs of parents in generation 27:
# parent_1: Individual(trace=[9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11], length=3484.0), parent_2: Individual(trace=[2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3], length=3484.0)
# ------------------------------------------------------------------------------
# 36th pairs of parents in generation 27:
# parent_1: Individual(trace=[2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3], length=3484.0), parent_2: Individual(trace=[7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11, 9, 8, 13], length=3484.0)
# spent_time for this request: 3.713481903076172
# crossover of 36th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 37th pairs of parents in generation 27:
# parent_1: Individual(trace=[1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2], length=3484.0), parent_2: Individual(trace=[9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10, 11], length=3484.0)
# ------------------------------------------------------------------------------
# 38th pairs of parents in generation 27:
# parent_1: Individual(trace=[1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2], length=3484.0), parent_2: Individual(trace=[12, 14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4], length=3484.0)
# spent_time for this request: 3.847623109817505
# crossover of 38th parents in generation 27
# child1 accepted!
# child2 accepted!
# time for muatating: 2.3882687091827393
# time for muatating: 2.3786537647247314
# ------------------------------------------------------------------------------
# 39th pairs of parents in generation 27:
# parent_1: Individual(trace=[4, 12, 14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5], length=3484.0), parent_2: Individual(trace=[11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1, 10], length=3484.0)
# spent_time for this request: 3.956740617752075
# crossover of 39th parents in generation 27
# child1 accepted!
# child2 accepted!
# time for muatating: 2.790282726287842
# time for muatating: 2.419684410095215
# ------------------------------------------------------------------------------
# 40th pairs of parents in generation 27:
# parent_1: Individual(trace=[10, 11, 9, 8, 13, 7, 6, 5, 4, 12, 14, 3, 2, 1], length=3484.0), parent_2: Individual(trace=[14, 3, 2, 1, 10, 11, 9, 8, 13, 7, 6, 5, 4, 12], length=3484.0)
# spent_time for this request: 3.6905956268310547
# crossover of 40th parents in generation 27
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# END generation: 27, best solution now is: 3484.0
# #######################################################################################
# got stuck 10 time
# 3484.0
