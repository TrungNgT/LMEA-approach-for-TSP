# %% [markdown]
# 0. Import modules

# %%
from support_pyfile import *
from additional_support_pyfile import *
from instance_pyfile import *

import time

# %% [markdown]
# 1. Config the LLM

# %%
import google.generativeai as genai

generation_config = {
    "temperature":0,
    "top_p":1,
    "top_k":1,
    "max_output_tokens":2048,
}

safety_settings = [
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_NONE"
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_NONE"
    }, 
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_NONE"
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_NONE"
    },
]


genai.configure(api_key='YOUR_API_KEY')

model = genai.GenerativeModel(model_name='gemini-pro', safety_settings=safety_settings)

# %% [markdown]
# 2. Prompt for crossover operator
# - Code: OX operator and PMX operator
# - prompt = (TSP_description + code) + operator_codes + examples + task_instruction

# %%
crx_description = 'You are given a list of points with coordinates: {' + list2str() + '}. A solution is a trace, with the shortest possible length, that traveles each point exactly once.\n'
crx_description += 'You will be given 2 parent solutions, your task is ONLY use one of the 2 Crossover operators provided below on the 2 parent solutions and generate 2 new Offsprings.'

trace_samples = 'Below are some previous traces and their lengths. The traces are arranged in descending order based on their lengths, where lower values are better.\n'
# remember to reduce N compare to the last algo

in_context = 'Now, there are Python code and some examples of the first Crossover operator. The examples consist of 2 parent traces and 2 new generated traces with explanations:\n'
in_context += ('import random \n def first_operator(parent1, parent2): \n size = len(parent1) \n #Step 1: Select random crossover range in both 2 parents, avoid the first and last gene \n start, end = sorted(random.sample(range(1, size-2), 2)) \n #Step 2: Create offspring by exchanging the selected range \n child1 = parent1[:start] + parent2[start:end] + parent1[end:] \n child2 = parent2[:start] + parent1[start:end] + parent2[end:] \n #Step 3: Determine the mapping relationship to legalize offspring \n mapping1 = {parent2[i]: parent1[i] for i in range(start, end)' + '}\n' + 'mapping 2 = {parent1[i]: parent2[i] for i in range(start, end)' + '}\n' + '#Step 4: Legalize children with the mapping relationship\n for i in list(range(start)) + list(range(end, size)): \n if child1[i] in mapping1:\n while child1[i] in mapping1: \n child1[i] = mapping1[child1[i]] \n if child2[i] in mapping2:\n while child2[i] in mapping2: \n child2[i] = mapping[child2[i]]\n return (child1, child2) \n return child1, child2 \n')
in_context += '{parent1 = [10, 5, 3, 19, 18, 11, 2, 14, 20, 12, 7, 21, 8, 6, 1, 17, 4, 9, 15, 13, 16, 22], parent2 = [20, 1, 4, 6, 2, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, 18, 17, 22]} {child1: [10, 1, 4, 6, 2, 11, 18, 14, 20, 12, 7, 21, 8, 19, 5, 17, 3, 9, 15, 13, 16, 22], child2: [20, 5, 3, 19, 18, 11, 8, 10, 6, 7, 9, 1, 12, 21, 13, 15, 16, 14, 4, 2, 17, 22]} Explanation: {Step 1: Select random crossover range in both 2 parents: (start=1, end=5); Step 2: Create offspring by exchanging the selected range: (child1=[10, 1, 4, 6, 2, 11, 2, 14, 20, 12, 7, 21, 8, 6, 1, 17, 4, 9, 15, 13, 16, 22], child2=[20, 5, 3, 19, 18, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, 18, 17, 22]); Step 3: Determine the mapping relationship to legalize offspring: (mapping1={1: 5, 4: 3, 6: 19, 2: 18}, mapping2={5: 1, 3: 4, 19: 6, 18: 2}); Step 4: Legalize children with the mapping relationsip and receive 2 result offsprings as shown.}\n'
in_context += '{parent1 = [10, 5, 3, 19, 18, 11, 2, 14, 20, 12, 7, 21, 8, 6, 1, 17, 4, 9, 15, 13, 16, 22], parent2 = [14, 19, 6, 21, 8, 5, 10, 1, 4, 13, 12, 18, 7, 11, 20, 3, 15, 16, 2, 9, 17, 22]} {child1: [2, 3, 6, 21, 8, 5, 10, 1, 4, 13, 12, 18, 7, 11, 20, 17, 14, 9, 15, 19, 16, 22], child2: [4, 13, 3, 19, 18, 11, 2, 14, 20, 12, 7, 21, 8, 6, 1, 5, 15, 16, 10, 9, 17, 22]} Explanation: {Step 1: Select random crossover range in both 2 parents: (start=2, end=15); Step 2: Create offspring by exchanging the selected range: (child1=[10, 5, 6, 21, 8, 5, 10, 1, 4, 13, 12, 18, 7, 11, 20, 17, 4, 9, 15, 13, 16, 22], child2=[14, 19, 3, 19, 18, 11, 2, 14, 20, 12, 7, 21, 8, 6, 1, 3, 15, 16, 2, 9, 17, 22]); Step 3: Determine the mapping relationship to legalize offspring: (mapping1={6: 3, 21: 19, 8: 18, 5: 11, 10: 2, 1: 14, 4: 20, 13: 12, 12: 7, 18: 21, 7: 8, 11: 6, 20: 1}, mapping2={3: 6, 19: 21, 18: 8, 11: 5, 2: 10, 14: 1, 20: 4, 12: 13, 7: 12, 21: 18, 8: 7, 6: 11, 1: 20}); Step 4: Legalize children with the mapping relationsip and receive 2 result offsprings as shown.}\n'
in_context += '{parent1 = [20, 1, 4, 6, 2, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, 18, 17, 22], parent2 = [14, 19, 6, 21, 8, 5, 10, 1, 4, 13, 12, 18, 7, 11, 20, 3, 15, 16, 2, 9, 17, 22]} {child1: [20, 8, 19, 6, 2, 21, 10, 1, 4, 13, 12, 18, 7, 11, 9, 15, 16, 14, 3, 5, 17, 22], child2: [14, 4, 6, 11, 1, 18, 8, 10, 19, 7, 9, 5, 12, 21, 20, 3, 15, 16, 2, 13, 17, 22]} Explanation: {Step 1: Select random crossover range in both 2 parents: (start=6, end=14); Step 2: Create offspring by exchanging the selected range: (child1=[20, 1, 4, 6, 2, 11, 10, 1, 4, 13, 12, 18, 7, 11, 13, 15, 16, 14, 3, 18, 17, 22], child2=[14, 19, 6, 21, 8, 5, 8, 10, 19, 7, 9, 5, 12, 21, 20, 3, 15, 16, 2, 9, 17, 22]); Step 3: Determine the mapping relationship to legalize offspring: (mapping1={10: 8, 1: 10, 4: 19, 13: 7, 12: 9, 18: 5, 7: 12, 11: 21}, mapping2={8: 10, 10: 1, 19: 4, 7: 13, 9: 12, 5: 18, 12: 7, 21: 11}); Step 4: Legalize children with the mapping relationsip and receive 2 result offsprings as shown.}\n'

in_context += 'Now, there are Python code and some examples of the second Crossover operator. The examples consist of 2 parent traces and 2 new generated traces with explanations:\n'
in_context += 'import random \n def second_operator(parent1, parent2): \n size = len(parent1) \n #Step 1: Select random crossover range in both 2 parents, avoid the first and last gene \n start, end = sorted(random.sample(range(1, size-2), 2)) \n # Step 2: Create proto-child by inheriting the selected range from its parent \n child1 = [None]*len(parent1) \n child1[start:end] = parent1[start:end] \n child2 = [None]*len(parent2) \n child2[start:end] = parent2[start:end] \n #Step 3: Fill in remaining positions in child1 with other cities in parent2 \n for i in range(len(parent2)):\n if parent2[i] not in child1:\n child1[child1.index(None)] = parent2[i] \n #Step 4: Fill in remaining positions in child2 with other cities in parent1: \n for i in range(len(parent1)):\n if parent1[i] not in child2:\n child2[child2.index(None)] = parent1[i] \n return child1, child2 \n'
in_context += '{parent1 = [20, 1, 4, 6, 2, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, 18, 17, 22], parent2 = [6, 8, 20, 1, 19, 21, 10, 11, 7, 12, 5, 9, 4, 3, 15, 16, 2, 14, 13, 18, 17, 22]} {child1: [6, 20, 1, 11, 4, 2, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, 18, 17, 22], child2: [20, 1, 6, 8, 19, 21, 10, 11, 7, 12, 5, 9, 4, 3, 15, 16, 2, 14, 13, 18, 17, 22]} Explanation: {Step 1: Select random crossover range in both 2 parents: (start=6, end=19); Step 2: Create proto-child by inheriting the selected range from its parent: (child1=[None, None, None, None, None, None, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, None, None, None], child2=[None, None, None, None, None, None, 10, 11, 7, 12, 5, 9, 4, 3, 15, 16, 2, 14, 13, None, None, None]); Step 3: Fill in remaining positions in child1 with other cities in parent2: child1=[6, 20, 1, 11, 4, 2, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, 18, 17, 22]; Step 4: Fill in remaining positions in child2 with other cities in parent1: child2=[20, 1, 6, 8, 19, 21, 10, 11, 7, 12, 5, 9, 4, 3, 15, 16, 2, 14, 13, 18, 17, 22]}\n'
in_context += '{parent1 = [16, 22, 15, 13, 14, 19, 6, 21, 8, 5, 10, 1, 4, 3, 12, 18, 7, 11, 20, 9, 17, 2], parent2 = [3, 12, 21, 8, 10, 19, 7, 11, 20, 1, 4, 6, 2, 14, 13, 16, 22, 15, 17, 18, 5, 9]} {child1: [21, 19, 6, 2, 14, 13, 16, 22, 8, 5, 10, 1, 4, 3, 12, 18, 7, 11, 20, 15, 17, 9], child2: [19, 21, 8, 5, 10, 3, 12, 18, 20, 1, 4, 6, 2, 14, 13, 16, 22, 15, 17, 7, 11, 9]} Explanation: {Step 1: Select random crossover range in both 2 parents: (start=8, end=19); Step 2: Create proto-child by inheriting the selected range from its parent: (child1=[None, None, None, None, None, None, None, None, 8, 5, 10, 1, 4, 3, 12, 18, 7, 11, 20, None, None, None], child2=[None, None, None, None, None, None, None, None, 20, 1, 4, 6, 2, 14, 13, 16, 22, 15, 17, None, None, None]); Step 3: Fill in remaining positions in child1 with other cities in parent2: child1=[21, 19, 6, 2, 14, 13, 16, 22, 8, 5, 10, 1, 4, 3, 12, 18, 7, 11, 20, 15, 17, 9]; Step 4: Fill in remaining positions in child2 with other cities in parent1: child2=[19, 21, 8, 5, 10, 3, 12, 18, 20, 1, 4, 6, 2, 14, 13, 16, 22, 15, 17, 7, 11, 9]}\n'
in_context += '{parent1 = [16, 22, 15, 13, 14, 19, 6, 21, 8, 5, 10, 1, 4, 3, 12, 18, 7, 11, 20, 9, 17, 2], parent2 = [1, 4, 6, 2, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 3, 18, 17, 22, 20]} {child1: [2, 11, 15, 13, 14, 19, 6, 21, 8, 5, 10, 1, 4, 3, 12, 18, 7, 9, 16, 17, 22, 20], child2: [22, 1, 6, 2, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 4, 3, 18, 20, 17]} Explanation: {Step 1: Select random crossover range in both 2 parents: (start=2, end=17); Step 2: Create proto-child by inheriting the selected range from its parent: (child1=[None, None, 15, 13, 14, 19, 6, 21, 8, 5, 10, 1, 4, 3, 12, 18, 7, None, None, None, None, None], child2=[None, None, 6, 2, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, None, None, None, None, None]); Step 3: Fill in remaining positions in child1 with other cities in parent2: child1=[2, 11, 15, 13, 14, 19, 6, 21, 8, 5, 10, 1, 4, 3, 12, 18, 7, 9, 16, 17, 22, 20]; Step 4: Fill in remaining positions in child2 with other cities in parent1: child2=[22, 1, 6, 2, 11, 8, 10, 19, 7, 9, 5, 12, 21, 13, 15, 16, 14, 4, 3, 18, 20, 17]}\n'

crx_task = 'Please follow the instruction step-by-step to generate 2 new offsprings:\n'
crx_task += '1. Now, you are given 2 parent solution traces: '
crx_task2 = '2. You can use ONE of the 2 mentioned Crossover Operators with the two traces in Step 1 to generate 2 new Offspring traces.'
crx_task2 += 'Directly give me 2 Offspring traces, bracketed the first Offspring with <Off1> and </Off1> and bracketed the second one with <Off2> and </Off2>. Not any explanation needed.'

# %% [markdown]
# 3. Prompt for Mutation Operator
# - Code: Towrs(), CIM(), RSM()
# - prompt = (TSP_description + examples) + operator_code + 3 examples + task_instruction

# %%
mut_description = 'You are given a list of points with coordinates: {' + list2str() + '}. A solution is a trace, with the shortest possible length, that traveles each point exactly once.\n'
mut_description += 'You now be given 1 solution traces, your task is to do Mutation it and give me the result.\n'

m_context = 'Now, there are Python code and some examples of the first Mutation operator. The examples consist of origin trace and the new generated trace with explanations:\n'
m_context += 'import random \n def first_operator(origin_trace): \n size = len(origin_trace) \n #Step 1: Randomly select 2 positions in the original trace \n position1, position2 = random.sample(range(1, size - 2), 2) \n # Step 2: Swap 2 genes in the positions selected aboved \n origin_trace[position1], origin_trace[position2] = origin_trace[position2], origin_trace[position1] \n'
m_context += '{origin_trace = [10, 14, 9, 8, 1, 6, 5, 11, 3, 12, 7, 13, 4, 2]}; {mutated_trace = [10, 14, 11, 8, 1, 6, 5, 9, 3, 12, 7, 13, 4, 2]} Explanation: {Step 1: Randomly select 2 positions in the original trace: (position1 = 2, position2 = 7); Step 2: Swap 2 genes in the positions selected aboved to get the mutated_trace = [10, 14, 11, 8, 1, 6, 5, 9, 3, 12, 7, 13, 4, 2]}\n'
m_context += '{origin_trace = [3, 2, 10, 7, 6, 11, 14, 1, 9, 13, 12, 5, 8, 4]}; {mutated_trace = [3, 9, 10, 7, 6, 11, 14, 1, 2, 13, 12, 5, 8, 4]} Explanation: {Step 1: Randomly select 2 positions in the original trace: (position1 = 8, position2 = 1); Step 2: Swap 2 genes in the positions selected aboved to get the mutated_trace = [3, 9, 10, 7, 6, 11, 14, 1, 2, 13, 12, 5, 8, 4]}\n'
m_context += '{origin_trace = [8, 7, 12, 14, 1, 3, 11, 6, 10, 4, 9, 13, 5, 2]}; {mutated_trace = [8, 7, 12, 14, 1, 3, 10, 6, 11, 4, 9, 13, 5, 2]} Explanation: {Step 1: Randomly select 2 positions in the original trace: (position1 = 6, position2 = 8); Step 2: Swap 2 genes in the positions selected aboved to get the mutated_trace = [8, 7, 12, 14, 1, 3, 10, 6, 11, 4, 9, 13, 5, 2]}\n'

m_context += 'Now, there are Python code and some examples of the second Mutation operator. The examples consist of origin trace and the new generated trace with explanations:\n'
m_context += 'import random \n def second_operator(origin_trace): \n size = len(origin_trace) \n #Step 1: Select a random point in the original trace \n point = random.randint(0, size - 1) \n # Step 2: Reverse all the sub-sequences from 0 to point and from point + 1 to the end \n     mutated_trace = origin_trace[:point][::-1] + origin_trace[point:][::-1] \n return mutated_trace \n'
m_context += '{origin_trace = [4, 1, 5, 14, 3, 9, 11, 7, 12, 13, 2, 8, 6, 10]}; {mutated_trace = [5, 1, 4, 10, 6, 8, 2, 13, 12, 7, 11, 9, 3, 14]} Explanation: {Step 1: Select a random point in the original trace: (point = 3); Step 2: Reverse all the sub-sequences from index = 0 to 3  and from index = 4 to the end of origin_trace, and get mutated_trace = [5, 1, 4, 10, 6, 8, 2, 13, 12, 7, 11, 9, 3, 14]}\n'
m_context += '{origin_trace = [10, 7, 5, 4, 9, 12, 3, 6, 14, 8, 1, 11, 13, 2]}; {mutated_trace = [14, 6, 3, 12, 9, 4, 5, 7, 10, 2, 13, 11, 1, 8]} Explanation: {Step 1: Select a random point in the original trace: (point = 9); Step 2: Reverse all the sub-sequences from index = 0 to 9  and from index = 10 to the end of origin_trace, and get mutated_trace = [14, 6, 3, 12, 9, 4, 5, 7, 10, 2, 13, 11, 1, 8]}\n'
m_context += '{origin_trace = [4, 6, 14, 9, 8, 10, 7, 13, 2, 1, 5, 3, 12, 11]}; {mutated_trace = [12, 3, 5, 1, 2, 13, 7, 10, 8, 9, 14, 6, 4, 11]} Explanation: {Step 1: Select a random point in the original trace: (point = 13); Step 2: Reverse all the sub-sequences from index = 0 to 13  and from index = 14 to the end of origin_trace, and get mutated_trace = [12, 3, 5, 1, 2, 13, 7, 10, 8, 9, 14, 6, 4, 11]}\n'

m_context += 'Now, there are Python code and some examples of the third Mutation operator. The examples consists of origin trace and the new generated trace with explanations.\n'
m_context += 'import random \n def third_operator(origin_trace): \n size = len(origin_trace) \n #Step 1: Select reverse range at random \n start, end = sorted(random.sample(range(1, size - 1), 2)) \n #Step 2: Reverse the sub-sequence from start to end to have the mutated trace \n     mutated_trace = origin_trace[:start] + origin_trace[start:end][::-1] + origin_trace[end:] \n return mutated_trace \n'
m_context += '{origin_trace = [1, 4, 13, 7, 10, 12, 6, 3, 8, 2, 11, 9, 5, 14]}; {mutated_trace = [1, 4, 13, 7, 10, 12, 8, 3, 6, 2, 11, 9, 5, 14]} Explanation: {Step 1: Select reverse range at random: (start = 6, end = 9); Step 2: Reverse the sub-sequence from index = 6 to 9 to have the mutated trace: [1, 4, 13, 7, 10, 12, 8, 3, 6, 2, 11, 9, 5, 14]}\n'
m_context += '{origin_trace = [2, 14, 4, 7, 10, 3, 8, 5, 1, 11, 12, 13, 6, 9]}; {mutated_trace = [2, 14, 4, 7, 10, 3, 8, 5, 1, 11, 12, 13, 6, 9]} Explanation: {Step 1: Select reverse range at random: (start = 6, end = 7); Step 2: Reverse the sub-sequence from index = 6 to 7 to have the mutated trace: [2, 14, 4, 7, 10, 3, 8, 5, 1, 11, 12, 13, 6, 9]}\n'
m_context += '{origin_trace = [14, 10, 5, 2, 13, 7, 12, 4, 8, 1, 3, 11, 6, 9]}; {mutated_trace = [14, 10, 5, 2, 13, 7, 1, 8, 4, 12, 3, 11, 6, 9]} Explanation: {Step 1: Select reverse range at random: (start = 6, end = 10); Step 2: Reverse the sub-sequence from index = 6 to 10 to have the mutated trace: [14, 10, 5, 2, 13, 7, 1, 8, 4, 12, 3, 11, 6, 9]}\n'

mut_task = 'Please follow the instruction step-by-step to generate 1 new mutated trace:\n'
mut_task += '1. Now, you are given a solution trace: '
mut_task2 = '2. You CAN use ONE of the 3 Mutation Operators aboved or combine them and generate NEW operator to mutate the given original trace in Step 1.'
mut_task2 += 'Directly give me the result, bracketed it with <mut> and </mut>. Not any explanation needed.'

# %%
best_cur = 99999999
best_now = 9999990

Pool = randomFirstN(n, N)

g = 1

# %%
while (g <= G and not check_stuck(best_cur, best_now, K=10)) :

    best_cur = Pool[N-1].length

    Pool_sharp = []

    for i in range(1, N+1) :
        
        par1, par2 = tournament_selection(Pool)

        print(f"{i}th pairs of parents in generation {g}:")

        print(f"parent_1: {par1}, parent_2: {par2}")

        if (random.random() < 0.7) :

            crosOv_prompt = crx_description + (trace_samples + pool2examples(Pool)) + in_context + crx_task + parent2str(par1, par2) + crx_task2

            start_time = time.time()

            response = model.generate_content(contents=crosOv_prompt)

            spent_time = time.time() - start_time

            print(f"spent_time for this request: {spent_time}")

            print(f"crossover of {i}th parents in generation {g}")
            child1, child2 = cut2Offsprings(response.text)
            #print(child1, child2)

            if checkPermu(child1, n):
                print("child1 accepted!")
                Pool_sharp.append(Individual(trace=traceStr2list(child1), length=objective_TSP(traceStr2list(child1))))
            if checkPermu(child2, n):
                print("child2 accepted!")
                Pool_sharp.append(Individual(trace=traceStr2list(child2), length=objective_TSP(traceStr2list(child2))))

            if (random.random() < 0.2) :

                for childStr in [child1, child2]:

                    mutate_prompt = mut_description + (trace_samples + pool2examples(Pool)) + m_context + (mut_task + childStr) + mut_task2

                    start_mut_time = time.time()

                    response_mut = model.generate_content(contents=mutate_prompt)

                    spent_time_mut = time.time() - start_mut_time

                    print(f"time for muatating: {spent_time_mut}")

                    sharp_childstr = cutMutated(response_mut.text)

                    if checkPermu(sharp_childstr, n):
                        Pool_sharp.append(Individual(trace=traceStr2list(sharp_childstr), length=objective_TSP(traceStr2list(sharp_childstr))))
                    
                    else:
                        print("!!! Fail mutation process")

        
        print("------------------------------------------------------------------------------")
    
    Pool = updatePool(Pool, Pool_sharp, N)

    best_now = Pool[N-1].length

    print(f"END generation: {g}, best solution now is: {best_now}")
    
    print("#######################################################################################")

    # checking diversity:
    if entropy_measuring(popu=Pool2list(Pool), pop_size=N, n=n, a=3, exp_thsh=5) == 0:
        print("Diversity: LOW!")
        Pool = rebuild(population=Pool, pop_size=N, n=n)
        print("Rebuilt the Pool!")
    

    g += 1


print(best_now)
# Out:
# got update!
# 1th pairs of parents in generation 1:
# parent_1: Individual(trace=[8, 14, 5, 10, 9, 11, 1, 12, 2, 13, 7, 3, 6, 4, 15], length=530.9941151461372), parent_2: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426)
# ------------------------------------------------------------------------------
# 2th pairs of parents in generation 1:
# parent_1: Individual(trace=[3, 1, 12, 14, 8, 15, 9, 2, 4, 11, 6, 13, 10, 7, 5], length=486.827926180349), parent_2: Individual(trace=[1, 9, 3, 14, 15, 7, 8, 2, 13, 12, 10, 4, 5, 6, 11], length=567.6533283790525)
# spent_time for this request: 4.683328866958618
# crossover of 2th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 3th pairs of parents in generation 1:
# parent_1: Individual(trace=[13, 12, 8, 5, 3, 1, 9, 10, 4, 2, 14, 6, 15, 7, 11], length=534.9139494380933), parent_2: Individual(trace=[9, 10, 2, 14, 3, 5, 11, 15, 12, 8, 4, 1, 7, 13, 6], length=513.8363226484812)
# ------------------------------------------------------------------------------
# 4th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 4, 12, 7, 5, 8, 15, 1, 10, 2, 6, 11, 3, 13, 14], length=532.5475663244711), parent_2: Individual(trace=[3, 1, 12, 14, 8, 15, 9, 2, 4, 11, 6, 13, 10, 7, 5], length=486.827926180349)
# spent_time for this request: 4.117393970489502
# crossover of 4th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 5th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426), parent_2: Individual(trace=[3, 15, 10, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 8], length=509.887763465084)
# ------------------------------------------------------------------------------
# 6th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426), parent_2: Individual(trace=[1, 9, 3, 14, 15, 7, 8, 2, 13, 12, 10, 4, 5, 6, 11], length=567.6533283790525)
# ------------------------------------------------------------------------------
# 7th pairs of parents in generation 1:
# parent_1: Individual(trace=[13, 12, 8, 2, 7, 11, 5, 14, 10, 4, 9, 6, 15, 3, 1], length=581.2735547053364), parent_2: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426)
# spent_time for this request: 4.043001890182495
# crossover of 7th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 8th pairs of parents in generation 1:
# parent_1: Individual(trace=[3, 15, 10, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 8], length=509.887763465084), parent_2: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426)
# spent_time for this request: 4.116158723831177
# crossover of 8th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 9th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426), parent_2: Individual(trace=[5, 13, 4, 7, 8, 15, 2, 11, 14, 12, 6, 1, 9, 3, 10], length=567.6221850129328)
# ------------------------------------------------------------------------------
# 10th pairs of parents in generation 1:
# parent_1: Individual(trace=[3, 15, 10, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 8], length=509.887763465084), parent_2: Individual(trace=[3, 10, 5, 1, 4, 6, 13, 14, 9, 7, 11, 15, 12, 2, 8], length=571.2430658910838)
# spent_time for this request: 4.009413242340088
# crossover of 10th parents in generation 1
# child1 accepted!
# child2 accepted!
# time for muatating: 2.726466178894043
# time for muatating: 2.8689563274383545
# ------------------------------------------------------------------------------
# 11th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 4, 12, 7, 5, 8, 15, 1, 10, 2, 6, 11, 3, 13, 14], length=532.5475663244711), parent_2: Individual(trace=[8, 14, 5, 10, 9, 11, 1, 12, 2, 13, 7, 3, 6, 4, 15], length=530.9941151461372)
# spent_time for this request: 3.8789451122283936
# crossover of 11th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 12th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 4, 10, 2, 7, 11, 8, 5, 13, 6, 12, 1, 15, 14, 3], length=558.278868152871), parent_2: Individual(trace=[6, 2, 7, 14, 11, 5, 1, 3, 12, 13, 9, 4, 10, 8, 15], length=518.2508455123877)
# spent_time for this request: 4.010389804840088
# crossover of 12th parents in generation 1
# child1 accepted!
# child2 accepted!
# time for muatating: 2.442497730255127
# time for muatating: 2.91081166267395
# ------------------------------------------------------------------------------
# 13th pairs of parents in generation 1:
# parent_1: Individual(trace=[1, 13, 4, 10, 7, 9, 14, 6, 5, 3, 12, 11, 2, 15, 8], length=572.3196603716264), parent_2: Individual(trace=[3, 15, 10, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 8], length=509.887763465084)
# spent_time for this request: 4.1510515213012695
# crossover of 13th parents in generation 1
# child1 accepted!
# child2 accepted!
# time for muatating: 2.704118013381958
# time for muatating: 2.6377763748168945
# ------------------------------------------------------------------------------
# 14th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426), parent_2: Individual(trace=[8, 14, 5, 10, 9, 11, 1, 12, 2, 13, 7, 3, 6, 4, 15], length=530.9941151461372)
# spent_time for this request: 4.006893873214722
# crossover of 14th parents in generation 1
# ------------------------------------------------------------------------------
# 15th pairs of parents in generation 1:
# parent_1: Individual(trace=[3, 15, 10, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 8], length=509.887763465084), parent_2: Individual(trace=[10, 12, 1, 4, 2, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11], length=515.4061514586292)
# ------------------------------------------------------------------------------
# 16th pairs of parents in generation 1:
# parent_1: Individual(trace=[8, 14, 5, 10, 9, 11, 1, 12, 2, 13, 7, 3, 6, 4, 15], length=530.9941151461372), parent_2: Individual(trace=[9, 4, 12, 7, 5, 8, 15, 1, 10, 2, 6, 11, 3, 13, 14], length=532.5475663244711)
# ------------------------------------------------------------------------------
# 17th pairs of parents in generation 1:
# parent_1: Individual(trace=[7, 1, 4, 3, 13, 11, 5, 8, 15, 12, 6, 14, 9, 2, 10], length=498.9857555790978), parent_2: Individual(trace=[3, 1, 12, 14, 8, 15, 9, 2, 4, 11, 6, 13, 10, 7, 5], length=486.827926180349)
# spent_time for this request: 4.106379985809326
# crossover of 17th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 18th pairs of parents in generation 1:
# parent_1: Individual(trace=[8, 14, 5, 10, 9, 11, 1, 12, 2, 13, 7, 3, 6, 4, 15], length=530.9941151461372), parent_2: Individual(trace=[10, 12, 1, 4, 2, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11], length=515.4061514586292)
# spent_time for this request: 4.022334098815918
# crossover of 18th parents in generation 1
# child1 accepted!
# child2 accepted!
# time for muatating: 2.813901662826538
# time for muatating: 2.4263694286346436
# ------------------------------------------------------------------------------
# 19th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 4, 12, 7, 5, 8, 15, 1, 10, 2, 6, 11, 3, 13, 14], length=532.5475663244711), parent_2: Individual(trace=[10, 12, 1, 4, 2, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11], length=515.4061514586292)
# spent_time for this request: 4.039597034454346
# crossover of 19th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 20th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426), parent_2: Individual(trace=[5, 13, 4, 7, 8, 15, 2, 11, 14, 12, 6, 1, 9, 3, 10], length=567.6221850129328)
# ------------------------------------------------------------------------------
# 21th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 10, 2, 14, 3, 5, 11, 15, 12, 8, 4, 1, 7, 13, 6], length=513.8363226484812), parent_2: Individual(trace=[9, 4, 12, 7, 5, 8, 15, 1, 10, 2, 6, 11, 3, 13, 14], length=532.5475663244711)
# spent_time for this request: 4.247390508651733
# crossover of 21th parents in generation 1
# child1 accepted!
# child2 accepted!
# time for muatating: 2.715566396713257
# time for muatating: 2.4112062454223633
# ------------------------------------------------------------------------------
# 22th pairs of parents in generation 1:
# parent_1: Individual(trace=[3, 1, 12, 14, 8, 15, 9, 2, 4, 11, 6, 13, 10, 7, 5], length=486.827926180349), parent_2: Individual(trace=[3, 15, 10, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 8], length=509.887763465084)
# spent_time for this request: 3.9876906871795654
# crossover of 22th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 23th pairs of parents in generation 1:
# parent_1: Individual(trace=[10, 12, 1, 4, 2, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11], length=515.4061514586292), parent_2: Individual(trace=[3, 15, 10, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 8], length=509.887763465084)
# spent_time for this request: 4.254034042358398
# crossover of 23th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 24th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 10, 2, 14, 3, 5, 11, 15, 12, 8, 4, 1, 7, 13, 6], length=513.8363226484812), parent_2: Individual(trace=[9, 4, 10, 2, 7, 11, 8, 5, 13, 6, 12, 1, 15, 14, 3], length=558.278868152871)
# spent_time for this request: 4.38739800453186
# crossover of 24th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 25th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 4, 12, 7, 5, 8, 15, 1, 10, 2, 6, 11, 3, 13, 14], length=532.5475663244711), parent_2: Individual(trace=[13, 12, 8, 5, 3, 1, 9, 10, 4, 2, 14, 6, 15, 7, 11], length=534.9139494380933)
# spent_time for this request: 4.167988300323486
# crossover of 25th parents in generation 1
# child1 accepted!
# child2 accepted!
# time for muatating: 2.5828263759613037
# time for muatating: 2.5452232360839844
# ------------------------------------------------------------------------------
# 26th pairs of parents in generation 1:
# parent_1: Individual(trace=[8, 14, 5, 10, 9, 11, 1, 12, 2, 13, 7, 3, 6, 4, 15], length=530.9941151461372), parent_2: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426)
# spent_time for this request: 4.021899700164795
# crossover of 26th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 27th pairs of parents in generation 1:
# parent_1: Individual(trace=[10, 12, 1, 4, 2, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11], length=515.4061514586292), parent_2: Individual(trace=[3, 1, 12, 14, 8, 15, 9, 2, 4, 11, 6, 13, 10, 7, 5], length=486.827926180349)
# ------------------------------------------------------------------------------
# 28th pairs of parents in generation 1:
# parent_1: Individual(trace=[8, 14, 5, 10, 9, 11, 1, 12, 2, 13, 7, 3, 6, 4, 15], length=530.9941151461372), parent_2: Individual(trace=[9, 10, 2, 14, 3, 5, 11, 15, 12, 8, 4, 1, 7, 13, 6], length=513.8363226484812)
# spent_time for this request: 4.221681833267212
# crossover of 28th parents in generation 1
# ------------------------------------------------------------------------------
# 29th pairs of parents in generation 1:
# parent_1: Individual(trace=[3, 1, 12, 14, 8, 15, 9, 2, 4, 11, 6, 13, 10, 7, 5], length=486.827926180349), parent_2: Individual(trace=[5, 14, 9, 12, 4, 15, 3, 7, 10, 6, 13, 1, 2, 8, 11], length=574.7098126107938)
# spent_time for this request: 4.151866912841797
# crossover of 29th parents in generation 1
# ------------------------------------------------------------------------------
# 30th pairs of parents in generation 1:
# parent_1: Individual(trace=[3, 15, 10, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 8], length=509.887763465084), parent_2: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426)
# spent_time for this request: 3.8729429244995117
# crossover of 30th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 31th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426), parent_2: Individual(trace=[1, 13, 4, 10, 7, 9, 14, 6, 5, 3, 12, 11, 2, 15, 8], length=572.3196603716264)
# ------------------------------------------------------------------------------
# 32th pairs of parents in generation 1:
# parent_1: Individual(trace=[13, 12, 8, 5, 3, 1, 9, 10, 4, 2, 14, 6, 15, 7, 11], length=534.9139494380933), parent_2: Individual(trace=[9, 4, 10, 2, 7, 11, 8, 5, 13, 6, 12, 1, 15, 14, 3], length=558.278868152871)
# spent_time for this request: 4.042044162750244
# crossover of 32th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 33th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 4, 10, 2, 7, 11, 8, 5, 13, 6, 12, 1, 15, 14, 3], length=558.278868152871), parent_2: Individual(trace=[7, 1, 4, 3, 13, 11, 5, 8, 15, 12, 6, 14, 9, 2, 10], length=498.9857555790978)
# spent_time for this request: 4.0853681564331055
# crossover of 33th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 34th pairs of parents in generation 1:
# parent_1: Individual(trace=[7, 1, 4, 3, 13, 11, 5, 8, 15, 12, 6, 14, 9, 2, 10], length=498.9857555790978), parent_2: Individual(trace=[9, 10, 2, 14, 3, 5, 11, 15, 12, 8, 4, 1, 7, 13, 6], length=513.8363226484812)
# spent_time for this request: 4.126449108123779
# crossover of 34th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 35th pairs of parents in generation 1:
# parent_1: Individual(trace=[10, 12, 1, 4, 2, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11], length=515.4061514586292), parent_2: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426)
# spent_time for this request: 5.104901075363159
# crossover of 35th parents in generation 1
# ------------------------------------------------------------------------------
# 36th pairs of parents in generation 1:
# parent_1: Individual(trace=[8, 14, 5, 10, 9, 11, 1, 12, 2, 13, 7, 3, 6, 4, 15], length=530.9941151461372), parent_2: Individual(trace=[10, 12, 1, 4, 2, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11], length=515.4061514586292)
# ------------------------------------------------------------------------------
# 37th pairs of parents in generation 1:
# parent_1: Individual(trace=[3, 1, 12, 14, 8, 15, 9, 2, 4, 11, 6, 13, 10, 7, 5], length=486.827926180349), parent_2: Individual(trace=[7, 1, 4, 3, 13, 11, 5, 8, 15, 12, 6, 14, 9, 2, 10], length=498.9857555790978)
# ------------------------------------------------------------------------------
# 38th pairs of parents in generation 1:
# parent_1: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426), parent_2: Individual(trace=[9, 4, 12, 7, 5, 8, 15, 1, 10, 2, 6, 11, 3, 13, 14], length=532.5475663244711)
# ------------------------------------------------------------------------------
# 39th pairs of parents in generation 1:
# parent_1: Individual(trace=[10, 12, 1, 4, 2, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11], length=515.4061514586292), parent_2: Individual(trace=[1, 9, 3, 14, 15, 7, 8, 2, 13, 12, 10, 4, 5, 6, 11], length=567.6533283790525)
# spent_time for this request: 3.9988605976104736
# crossover of 39th parents in generation 1
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 40th pairs of parents in generation 1:
# parent_1: Individual(trace=[3, 1, 12, 14, 8, 15, 9, 2, 4, 11, 6, 13, 10, 7, 5], length=486.827926180349), parent_2: Individual(trace=[6, 2, 7, 14, 11, 5, 1, 3, 12, 13, 9, 4, 10, 8, 15], length=518.2508455123877)
# spent_time for this request: 3.9713199138641357
# crossover of 40th parents in generation 1
# child1 accepted!
# child2 accepted!
# time for muatating: 2.8492729663848877
# time for muatating: 2.745798110961914
# ------------------------------------------------------------------------------
# END generation: 1, best solution now is: 432.9324784102208
# #######################################################################################
# got update!
# 1th pairs of parents in generation 2:
# parent_1: Individual(trace=[3, 15, 10, 11, 13, 12, 14, 8, 4, 2, 5, 7, 9, 6, 1], length=460.2242465588411), parent_2: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208)
# spent_time for this request: 4.0065248012542725
# crossover of 1th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 2th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208), parent_2: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426)
# ------------------------------------------------------------------------------
# 3th pairs of parents in generation 2:
# parent_1: Individual(trace=[3, 1, 12, 14, 8, 15, 2, 9, 4, 11, 6, 13, 10, 7, 5], length=486.45555759948036), parent_2: Individual(trace=[3, 15, 10, 11, 13, 12, 14, 8, 4, 2, 5, 7, 9, 6, 1], length=460.2242465588411)
# spent_time for this request: 3.771723508834839
# crossover of 3th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 4th pairs of parents in generation 2:
# parent_1: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438), parent_2: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208)
# ------------------------------------------------------------------------------
# 5th pairs of parents in generation 2:
# parent_1: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11, 1, 12, 2, 10], length=455.8100622066241), parent_2: Individual(trace=[3, 15, 10, 11, 13, 12, 14, 8, 4, 2, 5, 7, 9, 6, 1], length=460.2242465588411)
# spent_time for this request: 4.064112186431885
# crossover of 5th parents in generation 2
# child2 accepted!
# ------------------------------------------------------------------------------
# 6th pairs of parents in generation 2:
# parent_1: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426), parent_2: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438)
# spent_time for this request: 4.186938524246216
# crossover of 6th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 2.8966901302337646
# time for muatating: 2.7340035438537598
# ------------------------------------------------------------------------------
# 7th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208), parent_2: Individual(trace=[9, 6, 13, 11, 1, 12, 2, 10, 4, 5, 8, 3, 15, 7, 14], length=455.81006220662414)
# spent_time for this request: 3.859581470489502
# crossover of 7th parents in generation 2
# ------------------------------------------------------------------------------
# 8th pairs of parents in generation 2:
# parent_1: Individual(trace=[13, 12, 4, 7, 5, 8, 15, 1, 10, 9, 6, 11, 3, 2, 14], length=478.203348711528), parent_2: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438)
# ------------------------------------------------------------------------------
# 9th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208), parent_2: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426)
# ------------------------------------------------------------------------------
# 10th pairs of parents in generation 2:
# parent_1: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438), parent_2: Individual(trace=[7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 2, 1, 9, 8], length=488.3425614597054)
# spent_time for this request: 4.152653694152832
# crossover of 10th parents in generation 2
# child1 accepted!
# ------------------------------------------------------------------------------
# 11th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 12, 1, 3, 4, 11, 10], length=480.8007921490987), parent_2: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438)
# spent_time for this request: 3.9188194274902344
# crossover of 11th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 12th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208), parent_2: Individual(trace=[4, 10, 2, 9, 11, 8, 5, 13, 6, 12, 1, 15, 14, 3, 7], length=511.5449145533368)
# ------------------------------------------------------------------------------
# 13th pairs of parents in generation 2:
# parent_1: Individual(trace=[3, 15, 10, 11, 13, 12, 14, 8, 4, 2, 5, 7, 9, 6, 1], length=460.2242465588411), parent_2: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438)
# ------------------------------------------------------------------------------
# 14th pairs of parents in generation 2:
# parent_1: Individual(trace=[3, 15, 10, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 8], length=509.887763465084), parent_2: Individual(trace=[3, 1, 12, 14, 8, 15, 9, 2, 4, 11, 6, 13, 10, 7, 5], length=486.827926180349)
# spent_time for this request: 4.294225454330444
# crossover of 14th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 2.5410125255584717
# time for muatating: 2.5172157287597656
# ------------------------------------------------------------------------------
# 15th pairs of parents in generation 2:
# parent_1: Individual(trace=[15, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 3, 10, 8], length=456.9585768519082), parent_2: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11, 1, 12, 2, 10], length=455.8100622066241)
# ------------------------------------------------------------------------------
# 16th pairs of parents in generation 2:
# parent_1: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438), parent_2: Individual(trace=[13, 12, 4, 7, 5, 8, 15, 1, 10, 9, 6, 11, 3, 2, 14], length=478.203348711528)
# ------------------------------------------------------------------------------
# 17th pairs of parents in generation 2:
# parent_1: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426), parent_2: Individual(trace=[9, 10, 2, 14, 12, 7, 5, 8, 15, 1, 4, 13, 11, 3, 6], length=493.47289711466715)
# spent_time for this request: 4.217009782791138
# crossover of 17th parents in generation 2
# child1 accepted!
# ------------------------------------------------------------------------------
# 18th pairs of parents in generation 2:
# parent_1: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438), parent_2: Individual(trace=[3, 1, 12, 14, 8, 15, 9, 2, 4, 11, 6, 13, 10, 7, 5], length=486.827926180349)
# spent_time for this request: 3.923300266265869
# crossover of 18th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 19th pairs of parents in generation 2:
# parent_1: Individual(trace=[7, 1, 4, 3, 13, 11, 5, 8, 15, 12, 6, 14, 9, 2, 10], length=498.9857555790978), parent_2: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426)
# ------------------------------------------------------------------------------
# 20th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208), parent_2: Individual(trace=[3, 15, 10, 11, 13, 12, 14, 8, 4, 2, 5, 7, 9, 6, 1], length=460.2242465588411)
# ------------------------------------------------------------------------------
# 21th pairs of parents in generation 2:
# parent_1: Individual(trace=[9, 6, 13, 11, 1, 12, 2, 10, 4, 5, 8, 3, 15, 7, 14], length=455.81006220662414), parent_2: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208)
# spent_time for this request: 4.024402856826782
# crossover of 21th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 22th pairs of parents in generation 2:
# parent_1: Individual(trace=[13, 12, 4, 7, 5, 8, 15, 1, 10, 9, 6, 11, 3, 2, 14], length=478.203348711528), parent_2: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11, 1, 12, 2, 10], length=455.8100622066241)
# spent_time for this request: 4.179685831069946
# crossover of 22th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 23th pairs of parents in generation 2:
# parent_1: Individual(trace=[9, 6, 13, 11, 1, 12, 2, 10, 4, 5, 8, 3, 15, 7, 14], length=455.81006220662414), parent_2: Individual(trace=[10, 15, 12, 5, 7, 1, 9, 6, 8, 3, 4, 2, 14, 13, 11], length=506.4430663508141)
# ------------------------------------------------------------------------------
# 24th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208), parent_2: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11, 1, 12, 2, 10], length=455.8100622066241)
# spent_time for this request: 4.099622488021851
# crossover of 24th parents in generation 2
# ------------------------------------------------------------------------------
# 25th pairs of parents in generation 2:
# parent_1: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438), parent_2: Individual(trace=[3, 1, 12, 14, 8, 15, 2, 9, 4, 11, 6, 13, 10, 7, 5], length=486.45555759948036)
# spent_time for this request: 3.9904465675354004
# crossover of 25th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 26th pairs of parents in generation 2:
# parent_1: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426), parent_2: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208)
# ------------------------------------------------------------------------------
# 27th pairs of parents in generation 2:
# parent_1: Individual(trace=[9, 10, 2, 14, 12, 7, 5, 8, 15, 1, 4, 13, 11, 3, 6], length=493.47289711466715), parent_2: Individual(trace=[3, 15, 10, 11, 13, 12, 14, 8, 4, 2, 5, 7, 9, 6, 1], length=460.2242465588411)
# ------------------------------------------------------------------------------
# 28th pairs of parents in generation 2:
# parent_1: Individual(trace=[15, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 3, 10, 8], length=456.9585768519082), parent_2: Individual(trace=[7, 1, 8, 15, 12, 6, 14, 9, 2, 10, 13, 11, 5, 3, 4], length=511.0307526053714)
# spent_time for this request: 3.9168431758880615
# crossover of 28th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 3.007107973098755
# time for muatating: 2.555615186691284
# ------------------------------------------------------------------------------
# 29th pairs of parents in generation 2:
# parent_1: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438), parent_2: Individual(trace=[13, 12, 4, 7, 5, 8, 15, 1, 10, 9, 6, 11, 3, 2, 14], length=478.203348711528)
# spent_time for this request: 4.079888105392456
# crossover of 29th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 30th pairs of parents in generation 2:
# parent_1: Individual(trace=[9, 6, 13, 11, 1, 12, 2, 10, 4, 5, 8, 3, 15, 7, 14], length=455.81006220662414), parent_2: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208)
# spent_time for this request: 4.165368556976318
# crossover of 30th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 31th pairs of parents in generation 2:
# parent_1: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438), parent_2: Individual(trace=[7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 2, 1, 9, 8], length=488.3425614597054)
# ------------------------------------------------------------------------------
# 32th pairs of parents in generation 2:
# parent_1: Individual(trace=[15, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 3, 10, 8], length=456.9585768519082), parent_2: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 12, 1, 3, 4, 11, 10], length=480.8007921490987)
# ------------------------------------------------------------------------------
# 33th pairs of parents in generation 2:
# parent_1: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438), parent_2: Individual(trace=[3, 15, 10, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 8], length=509.887763465084)
# ------------------------------------------------------------------------------
# 34th pairs of parents in generation 2:
# parent_1: Individual(trace=[15, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 3, 10, 8], length=456.9585768519082), parent_2: Individual(trace=[3, 1, 12, 14, 8, 15, 9, 2, 4, 11, 6, 13, 10, 7, 5], length=486.827926180349)
# spent_time for this request: 3.9840657711029053
# crossover of 34th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 35th pairs of parents in generation 2:
# parent_1: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 12, 1, 3, 4, 11, 10], length=480.8007921490987), parent_2: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208)
# spent_time for this request: 4.155375957489014
# crossover of 35th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 36th pairs of parents in generation 2:
# parent_1: Individual(trace=[9, 6, 13, 11, 1, 12, 2, 10, 4, 5, 8, 3, 15, 7, 14], length=455.81006220662414), parent_2: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11, 1, 12, 2, 10], length=455.8100622066241)
# spent_time for this request: 3.947355031967163
# crossover of 36th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 2.4010636806488037
# time for muatating: 2.3890295028686523
# ------------------------------------------------------------------------------
# 37th pairs of parents in generation 2:
# parent_1: Individual(trace=[8, 14, 5, 10, 9, 11, 1, 12, 2, 13, 7, 3, 6, 4, 15], length=530.9941151461372), parent_2: Individual(trace=[3, 1, 12, 14, 8, 15, 9, 2, 4, 11, 6, 13, 10, 7, 5], length=486.827926180349)
# spent_time for this request: 3.9084370136260986
# crossover of 37th parents in generation 2
# child1 accepted!
# ------------------------------------------------------------------------------
# 38th pairs of parents in generation 2:
# parent_1: Individual(trace=[3, 1, 12, 14, 8, 15, 2, 9, 4, 11, 6, 13, 10, 7, 5], length=486.45555759948036), parent_2: Individual(trace=[10, 15, 12, 5, 7, 1, 9, 6, 8, 3, 4, 2, 14, 13, 11], length=506.4430663508141)
# spent_time for this request: 4.16593074798584
# crossover of 38th parents in generation 2
# child1 accepted!
# child2 accepted!
# time for muatating: 2.6120073795318604
# time for muatating: 2.47033953666687
# ------------------------------------------------------------------------------
# 39th pairs of parents in generation 2:
# parent_1: Individual(trace=[15, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 3, 10, 8], length=456.9585768519082), parent_2: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208)
# spent_time for this request: 3.8949668407440186
# crossover of 39th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 40th pairs of parents in generation 2:
# parent_1: Individual(trace=[3, 1, 12, 14, 8, 15, 2, 9, 4, 11, 6, 13, 10, 7, 5], length=486.45555759948036), parent_2: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426)
# spent_time for this request: 4.320972204208374
# crossover of 40th parents in generation 2
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# END generation: 2, best solution now is: 409.2289468662118
# #######################################################################################
# got update!
# 1th pairs of parents in generation 3:
# parent_1: Individual(trace=[7, 11, 13, 4, 15, 8, 3, 1, 12, 14, 2, 5, 9, 6, 10], length=435.6427512975995), parent_2: Individual(trace=[5, 7, 2, 9, 14, 13, 11, 1, 6, 3, 12, 4, 10, 15, 8], length=438.78668844916285)
# spent_time for this request: 4.125061511993408
# crossover of 1th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 2th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208), parent_2: Individual(trace=[7, 11, 13, 4, 15, 8, 3, 1, 12, 14, 2, 5, 9, 6, 10], length=435.6427512975995)
# spent_time for this request: 4.059589385986328
# crossover of 2th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 3th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 4, 3, 10, 11], length=448.4637095340253), parent_2: Individual(trace=[1, 11, 13, 9, 6, 14, 7, 15, 3, 8, 5, 4, 10, 2, 12], length=442.279988476167)
# spent_time for this request: 3.9337594509124756
# crossover of 3th parents in generation 3
# child1 accepted!
# ------------------------------------------------------------------------------
# 4th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 7, 2, 9, 14, 13, 11, 1, 6, 3, 12, 4, 10, 15, 8], length=438.78668844916285), parent_2: Individual(trace=[5, 7, 2, 10, 11, 4, 15, 8, 14, 12, 1, 3, 9, 6, 13], length=438.2197611706753)
# spent_time for this request: 4.137309312820435
# crossover of 4th parents in generation 3
# time for muatating: 2.7194788455963135
# !!! Fail mutation process
# time for muatating: 2.8676869869232178
# ------------------------------------------------------------------------------
# 5th pairs of parents in generation 3:
# parent_1: Individual(trace=[7, 11, 13, 4, 15, 8, 3, 1, 12, 14, 2, 5, 9, 6, 10], length=435.6427512975995), parent_2: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11, 1, 12, 2, 10], length=455.8100622066241)
# ------------------------------------------------------------------------------
# 6th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438), parent_2: Individual(trace=[5, 7, 2, 9, 14, 13, 11, 1, 6, 3, 12, 4, 10, 15, 8], length=438.78668844916285)
# spent_time for this request: 4.303839206695557
# crossover of 6th parents in generation 3
# ------------------------------------------------------------------------------
# 7th pairs of parents in generation 3:
# parent_1: Individual(trace=[9, 7, 11, 5, 12, 10, 4, 15, 13, 6, 14, 3, 8, 1, 2], length=456.99295893411426), parent_2: Individual(trace=[7, 11, 13, 4, 15, 8, 3, 1, 12, 14, 2, 5, 9, 6, 10], length=435.6427512975995)
# ------------------------------------------------------------------------------
# 8th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 4, 15, 8, 14, 12, 10, 11, 5, 7, 9, 6, 13, 3, 2], length=409.2289468662118), parent_2: Individual(trace=[5, 7, 2, 9, 14, 13, 11, 1, 6, 3, 12, 4, 10, 15, 8], length=438.78668844916285)
# ------------------------------------------------------------------------------
# 9th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 2, 6, 13, 14, 4, 15, 8, 12, 9, 5, 7, 3, 11, 10], length=459.6093081450752), parent_2: Individual(trace=[7, 11, 13, 4, 15, 8, 3, 1, 12, 14, 2, 5, 9, 6, 10], length=435.6427512975995)
# ------------------------------------------------------------------------------
# 10th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438), parent_2: Individual(trace=[5, 7, 2, 9, 14, 13, 11, 1, 6, 3, 12, 4, 10, 15, 8], length=438.78668844916285)
# spent_time for this request: 3.904247760772705
# crossover of 10th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 11th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 7, 2, 10, 11, 4, 15, 8, 14, 12, 1, 3, 9, 6, 13], length=438.2197611706753), parent_2: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 12, 1, 3, 4, 11, 10], length=480.8007921490987)
# ------------------------------------------------------------------------------
# 12th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 4, 15, 8, 14, 12, 10, 11, 5, 7, 9, 6, 13, 3, 2], length=409.2289468662118), parent_2: Individual(trace=[15, 10, 3, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 8], length=466.3448270146521)
# spent_time for this request: 4.0923027992248535
# crossover of 12th parents in generation 3
# child1 accepted!
# child2 accepted!
# time for muatating: 2.7068264484405518
# time for muatating: 2.6691794395446777
# ------------------------------------------------------------------------------
# 13th pairs of parents in generation 3:
# parent_1: Individual(trace=[9, 6, 13, 11, 1, 12, 2, 10, 4, 5, 8, 3, 15, 7, 14], length=455.81006220662414), parent_2: Individual(trace=[15, 11, 13, 4, 2, 14, 12, 5, 7, 1, 9, 6, 3, 10, 8], length=456.9585768519082)
# ------------------------------------------------------------------------------
# 14th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 4, 15, 8, 14, 12, 10, 11, 5, 7, 9, 6, 13, 3, 2], length=409.2289468662118), parent_2: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11, 1, 12, 2, 10], length=455.8100622066241)
# spent_time for this request: 3.9739201068878174
# crossover of 14th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 15th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 7, 2, 9, 14, 13, 11, 1, 6, 3, 12, 4, 10, 15, 8], length=438.78668844916285), parent_2: Individual(trace=[7, 11, 13, 4, 15, 8, 3, 1, 12, 14, 2, 5, 9, 6, 10], length=435.6427512975995)
# spent_time for this request: 4.20129132270813
# crossover of 15th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 16th pairs of parents in generation 3:
# parent_1: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 6, 13, 11, 9, 1, 12, 2, 10], length=450.34480165614633), parent_2: Individual(trace=[5, 7, 2, 9, 14, 13, 11, 1, 6, 3, 12, 4, 10, 15, 8], length=438.78668844916285)
# spent_time for this request: 3.8446271419525146
# crossover of 16th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 17th pairs of parents in generation 3:
# parent_1: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 6, 13, 11, 9, 1, 12, 2, 10], length=450.34480165614633), parent_2: Individual(trace=[1, 4, 15, 8, 14, 12, 10, 11, 5, 7, 9, 6, 13, 3, 2], length=409.2289468662118)
# ------------------------------------------------------------------------------
# 18th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 7, 2, 9, 14, 13, 11, 1, 6, 3, 12, 4, 10, 15, 8], length=438.78668844916285), parent_2: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208)
# spent_time for this request: 3.844066619873047
# crossover of 18th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 19th pairs of parents in generation 3:
# parent_1: Individual(trace=[7, 11, 13, 4, 15, 8, 3, 1, 12, 14, 2, 5, 9, 6, 10], length=435.6427512975995), parent_2: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438)
# spent_time for this request: 4.2473366260528564
# crossover of 19th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 20th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 4, 15, 8, 14, 12, 10, 11, 5, 7, 9, 6, 13, 3, 2], length=409.2289468662118), parent_2: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208)
# spent_time for this request: 4.72588324546814
# crossover of 20th parents in generation 3
# ------------------------------------------------------------------------------
# 21th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 4, 15, 8, 14, 12, 10, 11, 5, 7, 9, 6, 13, 3, 2], length=409.2289468662118), parent_2: Individual(trace=[1, 2, 6, 13, 14, 4, 15, 8, 12, 9, 5, 7, 3, 11, 10], length=459.6093081450752)
# spent_time for this request: 3.81516170501709
# crossover of 21th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 22th pairs of parents in generation 3:
# parent_1: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 6, 13, 11, 9, 1, 12, 2, 10], length=450.34480165614633), parent_2: Individual(trace=[5, 7, 2, 10, 11, 4, 15, 8, 14, 12, 1, 3, 9, 6, 13], length=438.2197611706753)
# spent_time for this request: 3.9411306381225586
# crossover of 22th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 23th pairs of parents in generation 3:
# parent_1: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11, 1, 12, 2, 10], length=455.8100622066241), parent_2: Individual(trace=[1, 4, 15, 8, 14, 12, 10, 11, 5, 7, 9, 6, 13, 3, 2], length=409.2289468662118)
# spent_time for this request: 4.035001277923584
# crossover of 23th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 24th pairs of parents in generation 3:
# parent_1: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 6, 13, 11, 9, 1, 12, 2, 10], length=450.34480165614633), parent_2: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11, 1, 12, 2, 10], length=455.8100622066241)
# spent_time for this request: 4.37679386138916
# crossover of 24th parents in generation 3
# time for muatating: 2.7243905067443848
# !!! Fail mutation process
# time for muatating: 2.5511341094970703
# ------------------------------------------------------------------------------
# 25th pairs of parents in generation 3:
# parent_1: Individual(trace=[5, 7, 2, 9, 14, 13, 11, 1, 6, 3, 12, 4, 10, 15, 8], length=438.78668844916285), parent_2: Individual(trace=[1, 2, 6, 13, 14, 4, 15, 8, 12, 9, 5, 7, 3, 11, 10], length=459.6093081450752)
# spent_time for this request: 4.054612636566162
# crossover of 25th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 26th pairs of parents in generation 3:
# parent_1: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 9, 6, 13, 11, 1, 12, 2, 10], length=455.8100622066241), parent_2: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 6, 13, 11, 9, 1, 12, 2, 10], length=450.34480165614633)
# spent_time for this request: 3.91513729095459
# crossover of 26th parents in generation 3
# child1 accepted!
# child2 accepted!
# time for muatating: 2.7032113075256348
# time for muatating: 2.781874179840088
# ------------------------------------------------------------------------------
# 27th pairs of parents in generation 3:
# parent_1: Individual(trace=[7, 11, 13, 4, 15, 8, 3, 1, 12, 14, 2, 5, 9, 6, 10], length=435.6427512975995), parent_2: Individual(trace=[1, 4, 15, 8, 14, 12, 10, 11, 5, 7, 9, 6, 13, 3, 2], length=409.2289468662118)
# spent_time for this request: 3.9242076873779297
# crossover of 27th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 28th pairs of parents in generation 3:
# parent_1: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 6, 13, 11, 9, 1, 12, 2, 10], length=450.34480165614633), parent_2: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 4, 3, 10, 11], length=448.4637095340253)
# spent_time for this request: 3.8995323181152344
# crossover of 28th parents in generation 3
# child1 accepted!
# child2 accepted!
# time for muatating: 2.736555814743042
# time for muatating: 2.71505069732666
# ------------------------------------------------------------------------------
# 29th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 11, 13, 9, 6, 14, 7, 15, 3, 8, 5, 4, 10, 2, 12], length=442.279988476167), parent_2: Individual(trace=[7, 11, 13, 4, 15, 8, 3, 1, 12, 14, 2, 5, 9, 6, 10], length=435.6427512975995)
# spent_time for this request: 4.008236885070801
# crossover of 29th parents in generation 3
# ------------------------------------------------------------------------------
# 30th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 11, 13, 9, 6, 14, 7, 15, 3, 8, 5, 4, 10, 2, 12], length=442.279988476167), parent_2: Individual(trace=[5, 7, 2, 9, 14, 13, 11, 1, 6, 3, 12, 4, 10, 15, 8], length=438.78668844916285)
# spent_time for this request: 4.084412336349487
# crossover of 30th parents in generation 3
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 31th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 11, 13, 9, 6, 14, 7, 15, 3, 8, 5, 4, 10, 2, 12], length=442.279988476167), parent_2: Individual(trace=[5, 7, 2, 9, 14, 6, 13, 15, 8, 1, 12, 3, 4, 10, 11], length=432.9324784102208)
# spent_time for this request: 3.8396012783050537
# crossover of 31th parents in generation 3
# child2 accepted!
# time for muatating: 2.537687301635742
# !!! Fail mutation process
# time for muatating: 2.6497433185577393
# ------------------------------------------------------------------------------
# 32th pairs of parents in generation 3:
# parent_1: Individual(trace=[1, 2, 10, 11, 13, 4, 15, 8, 14, 12, 5, 7, 9, 6, 3], length=450.20652227438), parent_2: Individual(trace=[4, 5, 8, 3, 15, 7, 14, 6, 13, 11, 9, 1, 12, 2, 10], length=450.34480165614633)
# ------------------------------------------------------------------------------
# 33th pairs of parents in generation 3:
# parent_1: Individual(trace=[7, 11, 13, 4, 15, 8, 3, 1, 12, 14, 2, 5, 9, 6, 10], length=435.6427512975995), parent_2: Individual(trace=[5, 7, 2, 9, 14, 13, 11, 1, 6, 3, 12, 4, 10, 15, 8], length=438.78668844916285)
# spent_time for this request: 4.163817405700684
# crossover of 33th parents in generation 3
# child1 accepted!
# child2 accepted!
# ...
# ------------------------------------------------------------------------------
# 27th pairs of parents in generation 25:
# parent_1: Individual(trace=[3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 2, 14, 12, 1], length=267.6116378427796), parent_2: Individual(trace=[6, 14, 2, 1, 12, 3, 10, 8, 15, 4, 5, 7, 11, 13, 9], length=264.80702688437066)
# ------------------------------------------------------------------------------
# 28th pairs of parents in generation 25:
# parent_1: Individual(trace=[15, 4, 10, 5, 7, 11, 13, 9, 6, 14, 2, 1, 12, 3, 8], length=275.9184393561515), parent_2: Individual(trace=[6, 14, 2, 1, 12, 3, 8, 15, 4, 10, 5, 7, 11, 13, 9], length=275.91843935615145)
# ------------------------------------------------------------------------------
# 29th pairs of parents in generation 25:
# parent_1: Individual(trace=[6, 14, 2, 1, 12, 3, 10, 8, 15, 4, 5, 7, 11, 13, 9], length=264.80702688437066), parent_2: Individual(trace=[2, 1, 12, 3, 4, 15, 8, 10, 5, 7, 11, 13, 9, 6, 14], length=275.91577992621006)
# ------------------------------------------------------------------------------
# 30th pairs of parents in generation 25:
# parent_1: Individual(trace=[3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 2, 14, 12, 1], length=267.6116378427796), parent_2: Individual(trace=[2, 14, 1, 12, 3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6], length=268.9215153507958)
# spent_time for this request: 4.104633569717407
# crossover of 30th parents in generation 25
# child1 accepted!
# child2 accepted!
# time for muatating: 2.8667831420898438
# time for muatating: 2.752793788909912
# ------------------------------------------------------------------------------
# 31th pairs of parents in generation 25:
# parent_1: Individual(trace=[10, 5, 7, 11, 13, 9, 6, 14, 2, 1, 12, 3, 8, 15, 4], length=275.9184393561515), parent_2: Individual(trace=[3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 2, 14, 12, 1], length=267.6116378427796)
# ------------------------------------------------------------------------------
# 32th pairs of parents in generation 25:
# parent_1: Individual(trace=[8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 2, 14, 1, 12, 3], length=268.9215153507958), parent_2: Individual(trace=[2, 1, 12, 3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 14], length=275.9184393561515)
# spent_time for this request: 4.00568962097168
# crossover of 32th parents in generation 25
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 33th pairs of parents in generation 25:
# parent_1: Individual(trace=[3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 2, 14, 12, 1], length=267.6116378427796), parent_2: Individual(trace=[6, 14, 2, 1, 12, 3, 10, 8, 15, 4, 5, 7, 11, 13, 9], length=264.80702688437066)
# spent_time for this request: 3.986555576324463
# crossover of 33th parents in generation 25
# child1 accepted!
# ------------------------------------------------------------------------------
# 34th pairs of parents in generation 25:
# parent_1: Individual(trace=[3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 2, 14, 12, 1], length=267.6116378427796), parent_2: Individual(trace=[6, 14, 2, 1, 12, 3, 10, 8, 15, 4, 5, 7, 11, 13, 9], length=264.80702688437066)
# spent_time for this request: 3.996664047241211
# crossover of 34th parents in generation 25
# child1 accepted!
# ------------------------------------------------------------------------------
# 35th pairs of parents in generation 25:
# parent_1: Individual(trace=[15, 8, 10, 5, 7, 11, 13, 9, 6, 14, 2, 1, 12, 3, 4], length=275.9157799262101), parent_2: Individual(trace=[8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 2, 14, 1, 12, 3], length=268.9215153507958)
# ------------------------------------------------------------------------------
# 36th pairs of parents in generation 25:
# parent_1: Individual(trace=[6, 14, 2, 1, 12, 3, 10, 8, 15, 4, 5, 7, 11, 13, 9], length=264.80702688437066), parent_2: Individual(trace=[3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 2, 14, 12, 1], length=267.6116378427796)
# spent_time for this request: 4.198304891586304
# crossover of 36th parents in generation 25
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 37th pairs of parents in generation 25:
# parent_1: Individual(trace=[15, 8, 10, 5, 7, 11, 13, 9, 6, 14, 2, 1, 12, 3, 4], length=275.9157799262101), parent_2: Individual(trace=[2, 1, 12, 3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 14], length=275.9184393561515)
# spent_time for this request: 4.097017765045166
# crossover of 37th parents in generation 25
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 38th pairs of parents in generation 25:
# parent_1: Individual(trace=[8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 14, 2, 1, 12, 3], length=275.9184393561515), parent_2: Individual(trace=[7, 11, 13, 9, 6, 14, 2, 1, 12, 3, 8, 15, 4, 10, 5], length=275.9184393561515)
# ------------------------------------------------------------------------------
# 39th pairs of parents in generation 25:
# parent_1: Individual(trace=[2, 14, 1, 12, 3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6], length=268.9215153507958), parent_2: Individual(trace=[10, 5, 7, 11, 13, 9, 6, 14, 2, 1, 12, 3, 4, 15, 8], length=275.9157799262101)
# spent_time for this request: 4.09014368057251
# crossover of 39th parents in generation 25
# ------------------------------------------------------------------------------
# 40th pairs of parents in generation 25:
# parent_1: Individual(trace=[2, 14, 1, 12, 3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6], length=268.9215153507958), parent_2: Individual(trace=[2, 1, 12, 3, 4, 15, 8, 10, 5, 7, 11, 13, 9, 6, 14], length=275.91577992621006)
# spent_time for this request: 4.0723700523376465
# crossover of 40th parents in generation 25
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# END generation: 25, best solution now is: 264.80702688437066
# #######################################################################################
# Diversity: LOW!
# Rebuilt the Pool!
# got stuck 2 time
# 1th pairs of parents in generation 26:
# parent_1: Individual(trace=[8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 14, 2, 1, 12, 3], length=275.9184393561515), parent_2: Individual(trace=[15, 8, 10, 5, 7, 11, 13, 9, 6, 14, 2, 1, 12, 3, 4], length=275.9157799262101)
# spent_time for this request: 3.990873336791992
# crossover of 1th parents in generation 26
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 2th pairs of parents in generation 26:
# parent_1: Individual(trace=[6, 2, 14, 1, 12, 3, 15, 8, 4, 10, 5, 7, 11, 13, 9], length=269.5292949125634), parent_2: Individual(trace=[10, 5, 7, 11, 13, 9, 6, 14, 2, 1, 12, 3, 4, 15, 8], length=275.9157799262101)
# ------------------------------------------------------------------------------
# 3th pairs of parents in generation 26:
# parent_1: Individual(trace=[3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 2, 14, 12, 1], length=267.6116378427796), parent_2: Individual(trace=[2, 14, 1, 12, 3, 15, 8, 4, 10, 5, 7, 11, 13, 9, 6], length=269.5292949125634)
# spent_time for this request: 4.106419324874878
# crossover of 3th parents in generation 26
# child1 accepted!
# child2 accepted!
# time for muatating: 2.6928904056549072
# time for muatating: 2.6256635189056396
# ------------------------------------------------------------------------------
# 4th pairs of parents in generation 26:
# parent_1: Individual(trace=[8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 2, 14, 1, 12, 3], length=268.9215153507958), parent_2: Individual(trace=[2, 1, 12, 3, 4, 15, 8, 10, 5, 7, 11, 13, 9, 6, 14], length=275.91577992621006)
# spent_time for this request: 4.118798732757568
# crossover of 4th parents in generation 26
# child1 accepted!
# child2 accepted!
# time for muatating: 2.854994773864746
# time for muatating: 2.5511510372161865
# ------------------------------------------------------------------------------
# 5th pairs of parents in generation 26:
# parent_1: Individual(trace=[2, 14, 1, 12, 3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6], length=268.9215153507958), parent_2: Individual(trace=[3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 2, 14, 12, 1], length=267.6116378427796)
# ------------------------------------------------------------------------------
# 6th pairs of parents in generation 26:
# parent_1: Individual(trace=[2, 14, 1, 12, 3, 15, 8, 4, 10, 5, 7, 11, 13, 9, 6], length=269.5292949125634), parent_2: Individual(trace=[3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6, 2, 14, 12, 1], length=267.6116378427796)
# spent_time for this request: 4.102737903594971
# crossover of 6th parents in generation 26
# child1 accepted!
# child2 accepted!
# time for muatating: 2.4661128520965576
# time for muatating: 2.565906047821045
# ------------------------------------------------------------------------------
# 7th pairs of parents in generation 26:
# parent_1: Individual(trace=[6, 2, 14, 1, 12, 3, 15, 8, 4, 10, 5, 7, 11, 13, 9], length=269.5292949125634), parent_2: Individual(trace=[10, 5, 7, 11, 13, 9, 6, 14, 2, 1, 12, 3, 4, 15, 8], length=275.9157799262101)
# spent_time for this request: 4.012107849121094
# crossover of 7th parents in generation 26
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 8th pairs of parents in generation 26:
# parent_1: Individual(trace=[2, 14, 1, 12, 3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6], length=268.9215153507958), parent_2: Individual(trace=[6, 14, 2, 1, 12, 3, 8, 15, 4, 10, 5, 7, 11, 13, 9], length=275.91843935615145)
# spent_time for this request: 4.054124355316162
# crossover of 8th parents in generation 26
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 9th pairs of parents in generation 26:
# parent_1: Individual(trace=[6, 14, 2, 1, 12, 3, 10, 8, 15, 4, 5, 7, 11, 13, 9], length=264.80702688437066), parent_2: Individual(trace=[15, 8, 10, 5, 7, 11, 13, 9, 6, 14, 2, 1, 12, 3, 4], length=275.9157799262101)
# spent_time for this request: 4.11173677444458
# crossover of 9th parents in generation 26
# child1 accepted!
# child2 accepted!
# ------------------------------------------------------------------------------
# 10th pairs of parents in generation 26:
# parent_1: Individual(trace=[10, 5, 7, 11, 13, 9, 6, 14, 2, 1, 12, 3, 4, 15, 8], length=275.9157799262101), parent_2: Individual(trace=[6, 2, 14, 1, 12, 3, 15, 8, 4, 10, 5, 7, 11, 13, 9], length=269.5292949125634)
# spent_time for this request: 3.9935402870178223
# crossover of 10th parents in generation 26
# child1 accepted!
# child2 accepted!
# time for muatating: 2.6732888221740723
# time for muatating: 2.8784518241882324
# ------------------------------------------------------------------------------
# 11th pairs of parents in generation 26:
# parent_1: Individual(trace=[6, 2, 14, 1, 12, 3, 15, 8, 4, 10, 5, 7, 11, 13, 9], length=269.5292949125634), parent_2: Individual(trace=[2, 14, 1, 12, 3, 8, 15, 4, 10, 5, 7, 11, 13, 9, 6], length=268.9215153507958)
# ---------------------------------------------------------------------------
# DeadlineExceeded                          Traceback (most recent call last)
# Cell In[6], line 21
#      17 crosOv_prompt = crx_description + (trace_samples + pool2examples(Pool)) + in_context + crx_task + parent2str(par1, par2) + crx_task2
#      19 start_time = time.time()
# ---> 21 response = model.generate_content(contents=crosOv_prompt)
#      23 spent_time = time.time() - start_time
#      25 print(f"spent_time for this request: {spent_time}")
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:827, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     824 self._validate_universe_domain()
#     826 # Send the request.
# --> 827 response = rpc(
#     828     request,
#     829     retry=retry,
#     830     timeout=timeout,
#     831     metadata=metadata,
#     832 )
#     834 # Done; return the response.
#     835 return response
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\retry\retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\retry\retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# DeadlineExceeded: 504 Deadline Exceeded
